# %% [markdown]
# ## 1. Создание предсказательной модели и оценивание её качества.

# %% [markdown]
# Считаем данные из скачанной открытой гугл-папки

# %%
import os
import pandas as pd
path = r'C:\Users\elena\Desktop\ВШЭ\MiniCourse\Public-data' 
data = {}

Data = []
Target = []

i=0
for dir_entry in sorted(os.listdir(path)):
    dir_entry_path = os.path.join(path, dir_entry)
    if os.path.isfile(dir_entry_path):
        i+=1
        with open(dir_entry_path, 'r') as my_file:
            print(dir_entry_path.split("\\")[-1])
            try:
                df = pd.read_csv(my_file, delimiter=';')
                if df.shape[1] == 5:
                    Data.append(df)
                    Target.append(dir_entry_path.split("\\")[-1])
            except UnicodeDecodeError:
                print(dir_entry_path.split("\\")[-1])
                pass

for dir_entry in sorted(os.listdir(path)):
    dir_entry_path = os.path.join(path, dir_entry)
    if os.path.isfile(dir_entry_path):
        i+=1
        with open(dir_entry_path, 'r') as my_file:
            print(dir_entry_path.split("\\")[-1])
            try:
                df = pd.read_csv(my_file, delimiter=',')
                if df.shape[1] == 5:
                    Data.append(df)
                    Target.append(dir_entry_path.split("\\")[-1])
            except UnicodeDecodeError:
                print(dir_entry_path.split("\\")[-1])
                pass
# Out:
# Aleksandr Pogodaev - Погодаев_бег_1
# Aleksandr Pogodaev - Погодаев_бег_2
# Aleksandr Pogodaev - Погодаев_бег_3
# Aleksandr Pogodaev - Погодаев_бег_4
# Aleksandr Pogodaev - Погодаев_езда_на_велосипеде_1
# Aleksandr Pogodaev - Погодаев_езда_на_велосипеде_2
# Aleksandr Pogodaev - Погодаев_езда_на_велосипеде_3
# Aleksandr Pogodaev - Погодаев_езда_на_велосипеде_4
# Aleksandr Pogodaev - Погодаев_подъем_по_лестнице_1
# Aleksandr Pogodaev - Погодаев_подъем_по_лестнице_2
# Aleksandr Pogodaev - Погодаев_подъем_по_лестнице_3
# Aleksandr Pogodaev - Погодаев_подъем_по_лестнице_4
# Aleksandr Pogodaev - Погодаев_стояние_на_месте_1
# Aleksandr Pogodaev - Погодаев_стояние_на_месте_2
# Aleksandr Pogodaev - Погодаев_стояние_на_месте_3
# Aleksandr Pogodaev - Погодаев_стояние_на_месте_4
# Aleksandr Pogodaev - Погодаев_ходьба_1
# Aleksandr Pogodaev - Погодаев_ходьба_2
# Aleksandr Pogodaev - Погодаев_ходьба_3
# Aleksandr Pogodaev - Погодаев_ходьба_4
# Alina Arslanova - Арсланова_поездки в автомобиле_1.uu
# Alina Arslanova - Арсланова_поездки в автомобиле_2.uu
# Alina Arslanova - Арсланова_поездки в автомобиле_3.uu
# Alina Arslanova - Арсланова_поездки в автомобиле_4.cpgz
# Alina Arslanova - Арсланова_поездки в автомобиле_4.cpgz
# Dima Sokolov - Соколов_Бег_1.csv
# Dima Sokolov - Соколов_Бег_2.csv
# Dima Sokolov - Соколов_Бег_3.csv
# Dima Sokolov - Соколов_Бег_4.csv
# Dima Sokolov - Соколов_Стояние_1.csv
# Dima Sokolov - Соколов_Стояние_2.csv
# Dima Sokolov - Соколов_Стояние_3.csv
# Dima Sokolov - Соколов_Стояние_4.csv
# Dima Sokolov - Соколов_Ходьба_1.csv.csv
# Dima Sokolov - Соколов_Ходьба_2.csv
# Dima Sokolov - Соколов_Ходьба_3.csv
# Dima Sokolov - Соколов_Ходьба_4.csv
# Dmitry - Колунтаев_автобус_1.csv
# Dmitry - Колунтаев_автомобиль_1.csv
# Dmitry - Колунтаев_автомобиль_2.csv
# Dmitry - Колунтаев_лестница_1.csv
# Dmitry - Колунтаев_лестница_2.csv
# Dmitry - Колунтаев_ходьба_1.csv
# Dmitry - Колунтаев_ходьба_2.csv
# Dmitry - Колунтаев_ходьба_3.csv
# Evgenia Mescheryakova - emesch_бег_1.uu
# Evgenia Mescheryakova - emesch_бег_2.uu
# Evgenia Mescheryakova - emesch_бег_3.uu
# Evgenia Mescheryakova - emesch_бег_4.uu
# Evgenia Mescheryakova - emesch_бег_5.uu
# Evgenia Mescheryakova - emesch_бег_6.uu
# Evgenia Mescheryakova - emesch_велосипед_1.uu
# Evgenia Mescheryakova - emesch_велосипед_2.uu
# Evgenia Mescheryakova - emesch_велосипед_3.uu
# Evgenia Mescheryakova - emesch_велосипед_4.uu
# Evgenia Mescheryakova - emesch_лестница_1.uu
# Evgenia Mescheryakova - emesch_стояние_1.uu
# Evgenia Mescheryakova - emesch_стояние_2.uu
# Evgenia Mescheryakova - emesch_стояние_3.uu
# Evgenia Mescheryakova - emesch_стояние_4.uu
# Evgenia Mescheryakova - emesch_стояние_5.uu
# Evgenia Mescheryakova - emesch_стояние_6.uu
# Evgenia Mescheryakova - emesch_ходьба_1.uu
# Maxim Mozgovoy - mmozgovoy_ходьба_4.csv
# Olga - OVP_стояние_на_месте.csv
# Olga - OVP_ходьба.csv
# Polina Roshchina - Рощина_автомобиль_1.csv
# Polina Roshchina - Рощина_автомобиль_2.csv
# Polina Roshchina - Рощина_автомобиль_3.csv
# Polina Roshchina - Рощина_автомобиль_4.csv
# Polina Roshchina - Рощина_бег_1.csv
# Polina Roshchina - Рощина_бег_2.csv
# Polina Roshchina - Рощина_бег_3.csv
# Polina Roshchina - Рощина_бег_4.csv
# Polina Roshchina - Рощина_велосипед_1.csv
# Polina Roshchina - Рощина_велосипед_2.csv
# Polina Roshchina - Рощина_велосипед_3.csv
# Polina Roshchina - Рощина_лестница_1.csv
# Polina Roshchina - Рощина_лестница_2.csv
# Polina Roshchina - Рощина_лестница_3.csv
# Polina Roshchina - Рощина_лестница_4.csv
# Polina Roshchina - Рощина_стояние_1.csv
# Polina Roshchina - Рощина_стояние_2.csv
# Polina Roshchina - Рощина_стояние_3.csv
# Polina Roshchina - Рощина_стояние_4.csv
# Polina Roshchina - Рощина_ходьба_1.csv
# Polina Roshchina - Рощина_ходьба_2.csv
# Polina Roshchina - Рощина_ходьба_3.csv
# Polina Roshchina - Рощина_ходьба_4.csv
# Rzhevskii Anatolii - paru4ik_ходьба_1.csv
# Rzhevskii Anatolii - paru4ik_ходьба_2.csv
# Rzhevskii Anatolii - paru4ik_ходьба_3.csv
# Rzhevskii Anatolii - paru4ik_ходьба_4.csv
# Rzhevskii Anatolii - paru4ik_ходьба_5.csv
# Rzhevskii Anatolii - paru4ik_электричка_1.csv
# Rzhevskii Anatolii - paru4ik_электричка_2.csv
# Rzhevskii Anatolii - paru4ik_электричка_3.csv
# Rzhevskii Anatolii - paru4ik_электричка_4.csv
# Sergey - DrM_автомобиль_1
# Sergey - DrM_автомобиль_2
# Sergey - DrM_автомобиль_3
# Sergey - DrM_автомобиль_4
# Sergey - DrM_бег_1
# Sergey - DrM_бег_2
# Sergey - DrM_бег_3
# Sergey - DrM_бег_4
# Sergey - DrM_лестница_1
# Sergey - DrM_лестница_2
# Sergey - DrM_лестница_3
# Sergey - DrM_лестница_4
# Sergey - DrM_стояние_1
# Sergey - DrM_стояние_2
# Sergey - DrM_стояние_3
# Sergey - DrM_стояние_4
# Sergey - DrM_ходьба_1
# Sergey - DrM_ходьба_2
# Sergey - DrM_ходьба_3
# Sergey - DrM_ходьба_4
# Vladimir - Бегемот_ходьба_1
# dimiii - 2021-07-23 20.51.28 - буба_велосипед_1.csv
# dimiii - буба_автомобиль_1.csv
# dimiii - буба_бег_1.csv
# dimiii - буба_бег_2.csv
# dimiii - буба_бег_3.csv
# dimiii - буба_велосипед_2.csv
# dimiii - буба_велосипед_3.csv
# dimiii - буба_велосипед_4.csv
# dimiii - буба_лестница_1.csv
# dimiii - буба_лестница_3.csv
# dimiii - буба_лестница_4.csv
# dimiii - буба_стояние_1.csv
# dimiii - буба_стояние_2.csv
# dimiii - буба_стояние_3.csv
# dimiii - буба_стояние_6.csv
# dimiii - буба_ходьба_1.csv
# dimiii - буба_ходьба_2.csv
# dimiii - буба_ходьба_3.csv
# tdiff - tdiff_вел_01
# tdiff - tdiff_вел_02
# tdiff - tdiff_вел_03
# tdiff - tdiff_вел_04
# tdiff - tdiff_вел_05
# Александр - ЧАЕ77_автобус_1
# Александр - ЧАЕ77_бег_1
# Александр - ЧАЕ77_бег_2
# Александр - ЧАЕ77_бег_3
# Александр - ЧАЕ77_бег_4
# Александр - ЧАЕ77_лестница_1
# Александр - ЧАЕ77_лестница_2
# Александр - ЧАЕ77_лестница_3
# Александр - ЧАЕ77_лестница_4
# Александр - ЧАЕ77_метро_1
# Александр - ЧАЕ77_метро_2
# Александр - ЧАЕ77_метро_3
# Александр - ЧАЕ77_метро_4
# Александр - ЧАЕ77_сидение_1
# Александр - ЧАЕ77_стояние_1
# Александр - ЧАЕ77_стояние_2
# Александр - ЧАЕ77_стояние_3
# Александр - ЧАЕ77_стояние_4
# Александр - ЧАЕ77_трамвай_1
# Александр - ЧАЕ77_трамвай_2
# Александр - ЧАЕ77_трамвай_3
# Александр - ЧАЕ77_трамвай_4
# Александр - ЧАЕ77_трамвай_6
# Александр - ЧАЕ77_трамвай_7
# Александр - ЧАЕ77_ходьба_1
# Александр - ЧАЕ77_ходьба_2
# Александр - ЧАЕ77_ходьба_3
# Александр - ЧАЕ77_ходьба_4
# Александр - ЧАЕ77_ходьба_6
# Алексей - Меглей_бег_1
# Алексей - Меглей_лестница_1
# Алексей - Меглей_стояние_1
# Алексей - Меглей_стояние_2
# Алексей - Меглей_ходьба_1
# Алмаз - Гизатуллин_бег_01
# Алмаз - Гизатуллин_бег_02
# Алмаз - Гизатуллин_бег_03
# Алмаз - Гизатуллин_бег_04
# Алмаз - Гизатуллин_велосипед_01
# Алмаз - Гизатуллин_велосипед_02
# Алмаз - Гизатуллин_велосипед_04
# Алмаз - Гизатуллин_велосипед_05
# Алмаз - Гизатуллин_лестница_01
# Алмаз - Гизатуллин_лестница_02
# Алмаз - Гизатуллин_лестница_03
# Алмаз - Гизатуллин_лестница_04
# Алмаз - Гизатуллин_стояние_01
# Алмаз - Гизатуллин_стояние_02
# Алмаз - Гизатуллин_стояние_03
# Алмаз - Гизатуллин_стояние_04
# Алмаз - Гизатуллин_ходьба_01
# Алмаз - Гизатуллин_ходьба_02
# Алмаз - Гизатуллин_ходьба_03
# Алмаз - Гизатуллин_ходьба_04
# Анастасия - Анастасия_бег_1.csv
# Анастасия - Анастасия_бег_2.csv
# Анастасия - Анастасия_бег_3.csv
# Анастасия - Анастасия_бег_4.csv
# Анастасия - Анастасия_подъем по лестнице_2.csv
# Анастасия - Анастасия_подъем по лестнице_3.csv
# Анастасия - Анастасия_подъем по лестнице_4.csv
# Анастасия - Анастасия_подъем по лестнице_5.csv
# Анастасия - Анастасия_поездка в автомобиле_1.csv
# Анастасия - Анастасия_стояние на месте_1.csv
# Анастасия - Анастасия_стояние на месте_2.csv
# Анастасия - Анастасия_стояние на месте_3.csv
# Анастасия - Анастасия_стояние на месте_5.csv
# Анастасия - Анастасия_ходьба_1.csv
# Анастасия - Анастасия_ходьба_3.csv
# Анастасия - Анастасия_ходьба_4.csv
# Анастасия - Анастасия_ходьба_5.csv
# Анна - Созонтова_лестница_1.csv
# Анна - Созонтова_лестница_2.csv
# Анна - Созонтова_лестница_3.csv
# Анна - Созонтова_лестница_4.csv
# Анна - Созонтова_стояние_1.csv
# Анна - Созонтова_стояние_2.csv
# Анна - Созонтова_стояние_3.csv
# Анна - Созонтова_стояние_4.csv
# Анна - Созонтова_ходьба_1.csv
# Анна - Созонтова_ходьба_2.csv
# Анна - Созонтова_ходьба_3.csv
# Анна - Созонтова_ходьба_4.csv
# Анна Сухова - Сухова_стояние_1.csv
# Анна Сухова - Сухова_стояние_2.csv
# Анна Сухова - Сухова_ходьба_1.csv
# Анна Сухова - Сухова_ходьба_2.csv
# Вячеслав - Барышев_автобус_1.csv
# Вячеслав - Барышев_автобус_2.csv
# Вячеслав - Барышев_автобус_3.csv
# Вячеслав - Барышев_бег_1.csv
# Вячеслав - Барышев_бег_2.csv
# Вячеслав - Барышев_бег_3.csv
# Вячеслав - Барышев_бег_4.csv
# Вячеслав - Барышев_велосипед_1.csv
# Вячеслав - Барышев_велосипед_2.csv
# Вячеслав - Барышев_велосипед_3.csv
# Вячеслав - Барышев_велосипед_4.csv
# Вячеслав - Барышев_лестница_1.csv
# Вячеслав - Барышев_лестница_2.csv
# Вячеслав - Барышев_лестница_3.csv
# Вячеслав - Барышев_лестница_4.csv
# Вячеслав - Барышев_метро_1.csv
# Вячеслав - Барышев_метро_2.csv
# Вячеслав - Барышев_стояние_1.csv
# Вячеслав - Барышев_стояние_2.csv
# Вячеслав - Барышев_стояние_3.csv
# Вячеслав - Барышев_стояние_4.csv
# Вячеслав - Барышев_ходьба_1.csv
# Вячеслав - Барышев_ходьба_2.csv
# Вячеслав - Барышев_ходьба_3.csv
# Вячеслав - Барышев_ходьба_4.csv
# Геннадий - бгм_лестница_1.csv
# Геннадий - бгм_лестница_2.csv
# Геннадий - бгм_лестница_3.csv
# Геннадий - бгм_лестница_4.csv
# Геннадий - бгм_стояние_1.csv
# Геннадий - бгм_стояние_2.csv
# Геннадий - бгм_стояние_3.csv
# Геннадий - бгм_стояние_4.csv
# Геннадий - бгм_ходьба_1.csv
# Геннадий - бгм_ходьба_2.csv
# Геннадий - бгм_ходьба_3.csv
# Геннадий - бгм_ходьба_4.csv
# Данила Котельников - Котельников_автомобиль_1.csv
# Данила Котельников - Котельников_автомобиль_2.csv
# Данила Котельников - Котельников_автомобиль_3.csv
# Данила Котельников - Котельников_автомобиль_4.csv
# Данила Котельников - Котельников_бег_1.csv
# Данила Котельников - Котельников_бег_2.csv
# Данила Котельников - Котельников_бег_3.csv
# Данила Котельников - Котельников_бег_4.csv
# Данила Котельников - Котельников_велосипед_1.csv
# Данила Котельников - Котельников_велосипед_2.csv
# Данила Котельников - Котельников_велосипед_3.csv
# Данила Котельников - Котельников_велосипед_4.csv
# Данила Котельников - Котельников_стояние_1.csv
# Данила Котельников - Котельников_стояние_2.csv
# Михаил - Mstr_ходьба_1.csv
# Наталья - Югансон_бег_1
# Наталья - Югансон_бег_2
# Наталья - Югансон_бег_3
# Наталья - Югансон_бег_4
# Наталья - Югансон_лестница_2
# Наталья - Югансон_лестница_3
# Наталья - Югансон_лестница_4
# Наталья - Югансон_лестница_5
# Наталья - Югансон_стояние_1
# Наталья - Югансон_стояние_2
# Наталья - Югансон_стояние_3
# Наталья - Югансон_стояние_4
# Наталья - Югансон_ходьба_1
# Наталья - Югансон_ходьба_2
# Наталья - Югансон_ходьба_3
# Наталья - Югансон_ходьба_4
# Никита - Бажов_Ходьба_1.csv
# Никита - Бажов_лестница_1.csv
# Никита - Бажов_ходьба_2.csv
# Никита - Никита_М_автобус_1
# Никита - Никита_М_автобус_2
# Никита - Никита_М_автобус_3
# Никита - Никита_М_автобус_4
# Никита - Никита_М_стояние_1
# Никита - Никита_М_стояние_2
# Никита - Никита_М_стояние_3
# Никита - Никита_М_стояние_4
# Никита - Никита_М_ходьба_1
# Никита - Никита_М_ходьба_2
# Никита - Никита_М_ходьба_3
# Никита - Никита_М_ходьба_4
# Оксана - Oksana_stairs_1.csv
# Оксана - Oksana_stairs_2.csv
# Оксана - Oksana_stairs_3.csv
# Оксана - Oksana_stairs_4.csv
# Оксана - Oksana_stand_1.csv
# Оксана - Oksana_stand_2.csv
# Оксана - Oksana_stand_3.csv
# Оксана - Oksana_stand_4.csv
# Олег - urev_автомобиль_1
# Олег - urev_автомобиль_2
# Олег - urev_автомобиль_3
# Олег - urev_автомобиль_4
# Олег - urev_бег_1
# Олег - urev_бег_2
# Олег - urev_бег_3
# Олег - urev_бег_4
# Олег - urev_велосипед_1
# Олег - urev_велосипед_2
# Олег - urev_велосипед_3
# Олег - urev_велосипед_4
# Олег - urev_стояние_1
# Олег - urev_стояние_2
# Олег - urev_стояние_3
# Олег - urev_стояние_4
# Олег - urev_ходьба_1
# Олег - urev_ходьба_2
# Олег - urev_ходьба_3
# Олег - urev_ходьба_4
# Олег Сахно - olegsakhno_бег_1.csv
# Олег Сахно - olegsakhno_бег_2.csv
# Олег Сахно - olegsakhno_бег_3.csv
# Олег Сахно - olegsakhno_бег_4.csv
# Олег Сахно - olegsakhno_лестница_1.csv
# Олег Сахно - olegsakhno_лестница_2.csv
# Олег Сахно - olegsakhno_лестница_3.csv
# Олег Сахно - olegsakhno_лестница_4.csv
# Олег Сахно - olegsakhno_стояние_1.csv
# Олег Сахно - olegsakhno_стояние_2.csv
# Олег Сахно - olegsakhno_стояние_3.csv
# Олег Сахно - olegsakhno_стояние_4.csv
# Олег Сахно - olegsakhno_ходьба_1.csv
# Олег Сахно - olegsakhno_ходьба_2.csv
# Олег Сахно - olegsakhno_ходьба_3.csv
# Олег Сахно - olegsakhno_ходьба_4.csv
# Олег Уфа - олегуфа_бег_1
# Олег Уфа - олегуфа_бег_2
# Олег Уфа - олегуфа_бег_3
# Олег Уфа - олегуфа_бег_4
# Олег Уфа - олегуфа_лестница_1
# Олег Уфа - олегуфа_лестница_2
# Олег Уфа - олегуфа_лестница_3
# Olga - OVP_стояние_на_месте.csv
# Olga - OVP_ходьба.csv
# Polina Roshchina - Рощина_автомобиль_1.csv
# Polina Roshchina - Рощина_автомобиль_2.csv
# Polina Roshchina - Рощина_автомобиль_3.csv
# Polina Roshchina - Рощина_автомобиль_4.csv
# Polina Roshchina - Рощина_бег_1.csv
# Polina Roshchina - Рощина_бег_2.csv
# Polina Roshchina - Рощина_бег_3.csv
# Polina Roshchina - Рощина_бег_4.csv
# Polina Roshchina - Рощина_велосипед_1.csv
# Polina Roshchina - Рощина_велосипед_2.csv
# Polina Roshchina - Рощина_велосипед_3.csv
# Polina Roshchina - Рощина_лестница_1.csv
# Polina Roshchina - Рощина_лестница_2.csv
# Polina Roshchina - Рощина_лестница_3.csv
# Polina Roshchina - Рощина_лестница_4.csv
# Polina Roshchina - Рощина_стояние_1.csv
# Polina Roshchina - Рощина_стояние_2.csv
# Polina Roshchina - Рощина_стояние_3.csv
# Polina Roshchina - Рощина_стояние_4.csv
# Polina Roshchina - Рощина_ходьба_1.csv
# Polina Roshchina - Рощина_ходьба_2.csv
# Polina Roshchina - Рощина_ходьба_3.csv
# Polina Roshchina - Рощина_ходьба_4.csv
# Rzhevskii Anatolii - paru4ik_ходьба_1.csv
# Rzhevskii Anatolii - paru4ik_ходьба_2.csv
# Rzhevskii Anatolii - paru4ik_ходьба_3.csv
# Rzhevskii Anatolii - paru4ik_ходьба_4.csv
# Rzhevskii Anatolii - paru4ik_ходьба_5.csv
# Rzhevskii Anatolii - paru4ik_электричка_1.csv
# Rzhevskii Anatolii - paru4ik_электричка_2.csv
# Rzhevskii Anatolii - paru4ik_электричка_3.csv
# Rzhevskii Anatolii - paru4ik_электричка_4.csv
# Sergey - DrM_автомобиль_1
# Sergey - DrM_автомобиль_2
# Sergey - DrM_автомобиль_3
# Sergey - DrM_автомобиль_4
# Sergey - DrM_бег_1
# Sergey - DrM_бег_2
# Sergey - DrM_бег_3
# Sergey - DrM_бег_4
# Sergey - DrM_лестница_1
# Sergey - DrM_лестница_2
# Sergey - DrM_лестница_3
# Sergey - DrM_лестница_4
# Sergey - DrM_стояние_1
# Sergey - DrM_стояние_2
# Sergey - DrM_стояние_3
# Sergey - DrM_стояние_4
# Sergey - DrM_ходьба_1
# Sergey - DrM_ходьба_2
# Sergey - DrM_ходьба_3
# Sergey - DrM_ходьба_4
# Vladimir - Бегемот_ходьба_1
# dimiii - 2021-07-23 20.51.28 - буба_велосипед_1.csv
# dimiii - буба_автомобиль_1.csv
# dimiii - буба_бег_1.csv
# dimiii - буба_бег_2.csv
# dimiii - буба_бег_3.csv
# dimiii - буба_велосипед_2.csv
# dimiii - буба_велосипед_3.csv
# dimiii - буба_велосипед_4.csv
# dimiii - буба_лестница_1.csv
# dimiii - буба_лестница_3.csv
# dimiii - буба_лестница_4.csv
# dimiii - буба_стояние_1.csv
# dimiii - буба_стояние_2.csv
# dimiii - буба_стояние_3.csv
# dimiii - буба_стояние_6.csv
# dimiii - буба_ходьба_1.csv
# dimiii - буба_ходьба_2.csv
# dimiii - буба_ходьба_3.csv
# tdiff - tdiff_вел_01
# tdiff - tdiff_вел_02
# tdiff - tdiff_вел_03
# tdiff - tdiff_вел_04
# tdiff - tdiff_вел_05
# Александр - ЧАЕ77_автобус_1
# Александр - ЧАЕ77_бег_1
# Александр - ЧАЕ77_бег_2
# Александр - ЧАЕ77_бег_3
# Александр - ЧАЕ77_бег_4
# Александр - ЧАЕ77_лестница_1
# Александр - ЧАЕ77_лестница_2
# Александр - ЧАЕ77_лестница_3
# Александр - ЧАЕ77_лестница_4
# Александр - ЧАЕ77_метро_1
# Александр - ЧАЕ77_метро_2
# Александр - ЧАЕ77_метро_3
# Александр - ЧАЕ77_метро_4
# Александр - ЧАЕ77_сидение_1
# Александр - ЧАЕ77_стояние_1
# Александр - ЧАЕ77_стояние_2
# Александр - ЧАЕ77_стояние_3
# Александр - ЧАЕ77_стояние_4
# Александр - ЧАЕ77_трамвай_1
# Александр - ЧАЕ77_трамвай_2
# Александр - ЧАЕ77_трамвай_3
# Александр - ЧАЕ77_трамвай_4
# Александр - ЧАЕ77_трамвай_6
# Александр - ЧАЕ77_трамвай_7
# Александр - ЧАЕ77_ходьба_1
# Александр - ЧАЕ77_ходьба_2
# Александр - ЧАЕ77_ходьба_3
# Александр - ЧАЕ77_ходьба_4
# Александр - ЧАЕ77_ходьба_6
# Алексей - Меглей_бег_1
# Алексей - Меглей_лестница_1
# Алексей - Меглей_стояние_1
# Алексей - Меглей_стояние_2
# Алексей - Меглей_ходьба_1
# Алмаз - Гизатуллин_бег_01
# Алмаз - Гизатуллин_бег_02
# Алмаз - Гизатуллин_бег_03
# Алмаз - Гизатуллин_бег_04
# Алмаз - Гизатуллин_велосипед_01
# Алмаз - Гизатуллин_велосипед_02
# Алмаз - Гизатуллин_велосипед_04
# Алмаз - Гизатуллин_велосипед_05
# Алмаз - Гизатуллин_лестница_01
# Алмаз - Гизатуллин_лестница_02
# Алмаз - Гизатуллин_лестница_03
# Алмаз - Гизатуллин_лестница_04
# Алмаз - Гизатуллин_стояние_01
# Алмаз - Гизатуллин_стояние_02
# Алмаз - Гизатуллин_стояние_03
# Алмаз - Гизатуллин_стояние_04
# Алмаз - Гизатуллин_ходьба_01
# Алмаз - Гизатуллин_ходьба_02
# Алмаз - Гизатуллин_ходьба_03
# Алмаз - Гизатуллин_ходьба_04
# Анастасия - Анастасия_бег_1.csv
# Анастасия - Анастасия_бег_2.csv
# Анастасия - Анастасия_бег_3.csv
# Анастасия - Анастасия_бег_4.csv
# Анастасия - Анастасия_подъем по лестнице_2.csv
# Анастасия - Анастасия_подъем по лестнице_3.csv
# Анастасия - Анастасия_подъем по лестнице_4.csv
# Анастасия - Анастасия_подъем по лестнице_5.csv
# Анастасия - Анастасия_поездка в автомобиле_1.csv
# Анастасия - Анастасия_стояние на месте_1.csv
# Анастасия - Анастасия_стояние на месте_2.csv
# Анастасия - Анастасия_стояние на месте_3.csv
# Анастасия - Анастасия_стояние на месте_5.csv
# Анастасия - Анастасия_ходьба_1.csv
# Анастасия - Анастасия_ходьба_3.csv
# Анастасия - Анастасия_ходьба_4.csv
# Анастасия - Анастасия_ходьба_5.csv
# Анна - Созонтова_лестница_1.csv
# Анна - Созонтова_лестница_2.csv
# Анна - Созонтова_лестница_3.csv
# Анна - Созонтова_лестница_4.csv
# Анна - Созонтова_стояние_1.csv
# Анна - Созонтова_стояние_2.csv
# Анна - Созонтова_стояние_3.csv
# Анна - Созонтова_стояние_4.csv
# Анна - Созонтова_ходьба_1.csv
# Анна - Созонтова_ходьба_2.csv
# Анна - Созонтова_ходьба_3.csv
# Анна - Созонтова_ходьба_4.csv
# Анна Сухова - Сухова_стояние_1.csv
# Анна Сухова - Сухова_стояние_2.csv
# Анна Сухова - Сухова_ходьба_1.csv
# Анна Сухова - Сухова_ходьба_2.csv
# Вячеслав - Барышев_автобус_1.csv
# Вячеслав - Барышев_автобус_2.csv
# Вячеслав - Барышев_автобус_3.csv
# Вячеслав - Барышев_бег_1.csv
# Вячеслав - Барышев_бег_2.csv
# Вячеслав - Барышев_бег_3.csv
# Вячеслав - Барышев_бег_4.csv
# Вячеслав - Барышев_велосипед_1.csv
# Вячеслав - Барышев_велосипед_2.csv
# Вячеслав - Барышев_велосипед_3.csv
# Вячеслав - Барышев_велосипед_4.csv
# Вячеслав - Барышев_лестница_1.csv
# Вячеслав - Барышев_лестница_2.csv
# Вячеслав - Барышев_лестница_3.csv
# Вячеслав - Барышев_лестница_4.csv
# Вячеслав - Барышев_метро_1.csv
# Вячеслав - Барышев_метро_2.csv
# Вячеслав - Барышев_стояние_1.csv
# Вячеслав - Барышев_стояние_2.csv
# Вячеслав - Барышев_стояние_3.csv
# Вячеслав - Барышев_стояние_4.csv
# Вячеслав - Барышев_ходьба_1.csv
# Вячеслав - Барышев_ходьба_2.csv
# Вячеслав - Барышев_ходьба_3.csv
# Вячеслав - Барышев_ходьба_4.csv
# Геннадий - бгм_лестница_1.csv
# Геннадий - бгм_лестница_2.csv
# Геннадий - бгм_лестница_3.csv
# Геннадий - бгм_лестница_4.csv
# Геннадий - бгм_стояние_1.csv
# Геннадий - бгм_стояние_2.csv
# Геннадий - бгм_стояние_3.csv
# Геннадий - бгм_стояние_4.csv
# Геннадий - бгм_ходьба_1.csv
# Геннадий - бгм_ходьба_2.csv
# Геннадий - бгм_ходьба_3.csv
# Геннадий - бгм_ходьба_4.csv
# Данила Котельников - Котельников_автомобиль_1.csv
# Данила Котельников - Котельников_автомобиль_2.csv
# Данила Котельников - Котельников_автомобиль_3.csv
# Данила Котельников - Котельников_автомобиль_4.csv
# Данила Котельников - Котельников_бег_1.csv
# Данила Котельников - Котельников_бег_2.csv
# Данила Котельников - Котельников_бег_3.csv
# Данила Котельников - Котельников_бег_4.csv
# Данила Котельников - Котельников_велосипед_1.csv
# Данила Котельников - Котельников_велосипед_2.csv
# Данила Котельников - Котельников_велосипед_3.csv
# Данила Котельников - Котельников_велосипед_4.csv
# Данила Котельников - Котельников_стояние_1.csv
# Данила Котельников - Котельников_стояние_2.csv
# Данила Котельников - Котельников_стояние_3.csv
# Данила Котельников - Котельников_стояние_4.csv
# Данила Котельников - Котельников_ходьба_1.csv
# Данила Котельников - Котельников_ходьба_2.csv
# Данила Котельников - Котельников_ходьба_3.csv
# Данила Котельников - Котельников_ходьба_4.csv
# Дария - ВоробьеваДВ_хотьба_1
# Дария - ВоробьеваДВ_хотьба_2
# Дария - ВоробьеваДВ_хотьба_3
# Дария - ВоробьеваДВ_хотьба_4
# Екатерина Митрохина - Митрохина_бег_1.csv
# Екатерина Митрохина - Митрохина_бег_2.csv
# Екатерина Митрохина - Митрохина_бег_3.csv
# Екатерина Митрохина - Митрохина_бег_4.csv
# Екатерина Митрохина - Митрохина_велосипед_1.csv
# Екатерина Митрохина - Митрохина_велосипед_2.csv
# Екатерина Митрохина - Митрохина_велосипед_3.csv
# Екатерина Митрохина - Митрохина_велосипед_4.csv
# Екатерина Митрохина - Митрохина_стояние_1.csv
# Екатерина Митрохина - Митрохина_стояние_2.csv
# Екатерина Митрохина - Митрохина_стояние_3.csv
# Екатерина Митрохина - Митрохина_стояние_4.csv
# Екатерина Митрохина - Митрохина_ходьба_1.csv
# Екатерина Митрохина - Митрохина_ходьба_2.csv
# Екатерина Митрохина - Митрохина_ходьба_3.csv
# Екатерина Митрохина - Митрохина_ходьба_4.csv
# Илья - Максименко_Лестница_1.csv
# Илья - Максименко_Лестница_2.csv
# Илья - Максименко_Лестница_3.csv
# Илья - Максименко_Стояние_1.csv
# Илья - Максименко_Стояние_2.csv
# Илья - Максименко_Стояние_3.csv
# Илья - Максименко_Стояние_4.csv
# Илья - Максименко_Ходьба_1.csv
# Илья - Максименко_Ходьба_2.csv
# Илья - Максименко_Ходьба_3.csv
# Илья - Максименко_Ходьба_4.csv
# Кермен - малашева_бег_1.csv
# Кермен - малашева_бег_2.csv
# Кермен - малашева_бег_3.csv
# Кермен - малашева_бег_4.csv
# Кермен - малашева_лестница_1.csv
# Кермен - малашева_лестница_2.csv
# Кермен - малашева_лестница_3.csv
# Кермен - малашева_лестница_4.csv
# Кермен - малашева_стояние_1.csv
# Кермен - малашева_стояние_2.csv
# Кермен - малашева_стояние_3.csv
# Кермен - малашева_стояние_4.csv
# Кермен - малашева_ходьба_1.csv
# Кермен - малашева_ходьба_2.csv
# Кермен - малашева_ходьба_3.csv
# Кермен - малашева_ходьба_4.csv
# Мажорова Инна - Мажорова-велосипед_1
# Мажорова Инна - Мажорова_велосипед_2
# Максим - 2021-07-24 18.24.16 - Лобода_ходьба_1
# Максим - Лобода_бег_1
# Максим - Лобода_бег_2
# Максим - Лобода_бег_3
# Максим - Лобода_бег_4
# Максим - Лобода_лестница_1
# Максим - Лобода_лестница_2
# Максим - Лобода_лестница_3
# Максим - Лобода_лестница_4
# Максим - Лобода_стояние_1
# Максим - Лобода_стояние_2
# Максим - Лобода_стояние_3
# Максим - Лобода_стояние_4
# Максим - Лобода_ходьба_1
# Максим - Лобода_ходьба_2
# Максим - Лобода_ходьба_3
# Максим - Лобода_ходьба_4
# Михаил - Mstr_лестница_1.csv
# Михаил - Mstr_ходьба_1.csv
# Наталья - Югансон_бег_1
# Наталья - Югансон_бег_2
# Наталья - Югансон_бег_3
# Наталья - Югансон_бег_4
# Наталья - Югансон_лестница_2
# Наталья - Югансон_лестница_3
# Наталья - Югансон_лестница_4
# Наталья - Югансон_лестница_5
# Наталья - Югансон_стояние_1
# Наталья - Югансон_стояние_2
# Наталья - Югансон_стояние_3
# Наталья - Югансон_стояние_4
# Наталья - Югансон_ходьба_1
# Наталья - Югансон_ходьба_2
# Наталья - Югансон_ходьба_3
# Наталья - Югансон_ходьба_4
# Никита - Бажов_Ходьба_1.csv
# Никита - Бажов_лестница_1.csv
# Никита - Бажов_ходьба_2.csv
# Никита - Никита_М_автобус_1
# Никита - Никита_М_автобус_2
# Никита - Никита_М_автобус_3
# Никита - Никита_М_автобус_4
# Никита - Никита_М_стояние_1
# Никита - Никита_М_стояние_2
# Никита - Никита_М_стояние_3
# Никита - Никита_М_стояние_4
# Никита - Никита_М_ходьба_1
# Никита - Никита_М_ходьба_2
# Никита - Никита_М_ходьба_3
# Никита - Никита_М_ходьба_4
# Оксана - Oksana_stairs_1.csv
# Оксана - Oksana_stairs_2.csv
# Оксана - Oksana_stairs_3.csv
# Оксана - Oksana_stairs_4.csv
# Оксана - Oksana_stand_1.csv
# Оксана - Oksana_stand_2.csv
# Оксана - Oksana_stand_3.csv
# Оксана - Oksana_stand_4.csv
# Олег - urev_автомобиль_1
# Олег - urev_автомобиль_2
# Олег - urev_автомобиль_3
# Олег - urev_автомобиль_4
# Олег - urev_бег_1
# Олег - urev_бег_2
# Олег - urev_бег_3
# Олег - urev_бег_4
# Олег - urev_велосипед_1
# Олег - urev_велосипед_2
# Олег - urev_велосипед_3
# Олег - urev_велосипед_4
# Олег - urev_стояние_1
# Олег - urev_стояние_2
# Олег - urev_стояние_3
# Олег - urev_стояние_4
# Олег - urev_ходьба_1
# Олег - urev_ходьба_2
# Олег - urev_ходьба_3
# Олег - urev_ходьба_4
# Олег Сахно - olegsakhno_бег_1.csv
# Олег Сахно - olegsakhno_бег_2.csv
# Олег Сахно - olegsakhno_бег_3.csv
# Олег Сахно - olegsakhno_бег_4.csv
# Олег Сахно - olegsakhno_лестница_1.csv
# Олег Сахно - olegsakhno_лестница_2.csv
# Олег Сахно - olegsakhno_лестница_3.csv
# Олег Сахно - olegsakhno_лестница_4.csv
# Олег Сахно - olegsakhno_стояние_1.csv
# Олег Сахно - olegsakhno_стояние_2.csv
# Олег Сахно - olegsakhno_стояние_3.csv
# Олег Сахно - olegsakhno_стояние_4.csv
# Олег Сахно - olegsakhno_ходьба_1.csv
# Олег Сахно - olegsakhno_ходьба_2.csv
# Олег Сахно - olegsakhno_ходьба_3.csv
# Олег Сахно - olegsakhno_ходьба_4.csv
# Олег Уфа - олегуфа_бег_1
# Олег Уфа - олегуфа_бег_2
# Олег Уфа - олегуфа_бег_3
# Олег Уфа - олегуфа_бег_4
# Олег Уфа - олегуфа_лестница_1
# Олег Уфа - олегуфа_лестница_2
# Олег Уфа - олегуфа_лестница_3
# Олег Уфа - олегуфа_лестница_4
# Олег Уфа - олегуфа_стояние_1
# %%
def get_type(name):
    return name.split("_")[-2]

# %% [markdown]
# Переведём типы движений в числа

# %%
classes = {'тояни' : 0, 'месте' : 0, 'одьб' : 1, 'аг' : 1, 'ег' : 2, 'елоси' : 3, 'естн' : 4, 'одъ' : 4, 
           'втомо' : 5, 'ашин' : 5, 'метро' : 6, 'автоб' : 7, 'амок' : 8}

answers = {'стояние' : 0, 'ходьба' : 1, 'бег' : 2, 'велосипед' : 3, 'лестница' : 4, 
           'автомобиль' : 5, 'метро' : 6, 'автобус' : 7, 'самокат' : 8}

# стояние, ходьба, велосипед, лестница, бег, подъем, подъём, автомобиль, электросамокат, машина, метро

# %%
def get_action(name):
    for act in classes:
        if name.lower().find(act) != -1:
            return classes[act]
    return -1

# %%
# s1 = "Happy birthday"
# s2 = "sdjksdlgjls"

# s1.find(s2)

# %% [markdown]
# Обработаем данные и извлечём признаки для создания модели

# %%
import pandas as pd
from matplotlib import pylab as plt
# %pylab inline

def process_data(df, comma=True, cut=True, name = "", a=-1, b=-1):
    
# обрезаем начало и конец трека
    if a == -1:
        st = int(0.2*len(df))
    else:
        st = a
            
    if b == -1:
        end = -int(0.2*len(df))
    else:
        end = b
        
    if cut == False:
        st = 0
        end = -1

    print(name)
#     fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2, figsize=(15,6))

# приводим данные с Iphone к нужному формату
    if comma is True:
        df = df.applymap(lambda x: str(x).replace(',','.'))
        
        try:
            df['gFx'] = df['gFx'].astype(float)
            df['gFy'] = df['gFy'].astype(float)
            df['gFz'] = df['gFz'].astype(float)
        except KeyError:
            return -1

# рисуем графики ускорений
#     if cut:
#         ax1.plot(df.iloc[st:end]['gFx'],c='g')
#         ax1.plot(df.iloc[st:end]['gFy'],c='r')
#         ax1.plot(df.iloc[st:end]['gFz'],c='b')
#     else:
#         ax1.plot(df['gFx'],c='g')
#         ax1.plot(df['gFy'],c='r')
#         ax1.plot(df['gFz'],c='b')
        
# вычисляем модуль (норму) ускорения и рисуем его
    Acc = (df.gFx[st:end] ** 2 + df.gFy[st:end] ** 2 + df.gFz[st:end] ** 2) ** 0.5
#     ax2.plot(Acc)
#     plt.show()

# можно различить многие действия по амплитуде ускорения
    amplitude = Acc.max() - Acc.min()
    print(' АМПЛИТУДА:', Acc.max()-Acc.min())
    print()
    
    return amplitude

Ampl = []

for df, target in zip(Data,Target):
    track_type = get_type(target)
    Ampl.append(process_data(df, name=track_type))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# поездки в автомобиле
#  АМПЛИТУДА: 1.2934885839535286
#
# поездки в автомобиле
#  АМПЛИТУДА: 1.378314900590001
#
# поездки в автомобиле
# C:\Users\elena\AppData\Roaming\Python\Python37\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
#  АМПЛИТУДА: 1.0204367627944797
#
# Бег
#  АМПЛИТУДА: 2.468601670411978
#
# Бег
# Бег
# Бег
# Стояние
# Стояние
#  АМПЛИТУДА: 3.355037229750099
#
# Стояние
# Стояние
# Ходьба
# Ходьба
# Ходьба
# Ходьба
#  АМПЛИТУДА: 0.7300797701761894
#
# лестница
#  АМПЛИТУДА: 5.576719369879306
#
# стояние
#  АМПЛИТУДА: 1.0470360582064422
#
# ходьба
#  АМПЛИТУДА: 3.189845479550237
#
# подъем
#  АМПЛИТУДА: 0.8466408755374216
#
# подъем
#  АМПЛИТУДА: 3.144663056836177
#
# подъем
#  АМПЛИТУДА: 1.6707723086479365
#
# подъем
#  АМПЛИТУДА: 1.602725944490252
#
# подъем
#  АМПЛИТУДА: 1.5942396869242157
#
# стояние
#  АМПЛИТУДА: 0.28234293265072663
#
# стояние
#  АМПЛИТУДА: 0.11323565987057882
#
# стояние
#  АМПЛИТУДА: 0.37896051441031176
#
# стояние
#  АМПЛИТУДА: 0.06447818752784229
#
# стояние
#  АМПЛИТУДА: 0.39951874941545984
#
# ходьба
#  АМПЛИТУДА: 4.016336069975719
#
# ходьба
#  АМПЛИТУДА: 3.867018681101632
#
# ходьба
#  АМПЛИТУДА: 4.092119841430777
#
# ходьба
#  АМПЛИТУДА: 4.464597458624001
#
# ходьба
#  АМПЛИТУДА: 6.101493602995067
#
# автобус
#  АМПЛИТУДА: 1.7809131888353202
#
# бег
#  АМПЛИТУДА: 4.620927743028751
#
# бег
#  АМПЛИТУДА: 5.498486455432361
#
# бег
#  АМПЛИТУДА: 4.551653127980187
#
# бег
#  АМПЛИТУДА: 6.790068479222559
#
# лестница
#  АМПЛИТУДА: 1.6642329650484113
#
# лестница
#  АМПЛИТУДА: 1.3076868587093466
#
# лестница
#  АМПЛИТУДА: 2.3975056669325787
#
# лестница
#  АМПЛИТУДА: 1.7294218381683337
#
# метро
#  АМПЛИТУДА: 0.45596001293757016
#
# метро
#  АМПЛИТУДА: 0.3293020052771748
#
# метро
#  АМПЛИТУДА: 0.8656158748229049
#
# метро
#  АМПЛИТУДА: 0.7931284340290213
#
# сидение
#  АМПЛИТУДА: 0.010422644465218789
#
# стояние
#  АМПЛИТУДА: 1.5647927977775886
#
# стояние
#  АМПЛИТУДА: 0.060502171318068454
#
# стояние
#  АМПЛИТУДА: 0.07714048754566272
#
# стояние
#  АМПЛИТУДА: 0.01919066070774822
#
# трамвай
#  АМПЛИТУДА: 0.23392401671831375
#
# трамвай
#  АМПЛИТУДА: 0.20163603734344548
#
# трамвай
#  АМПЛИТУДА: 0.35866546254735143
#
# трамвай
#  АМПЛИТУДА: 0.12091121670760219
#
# трамвай
#  АМПЛИТУДА: 0.3989917451273225
#
# трамвай
#  АМПЛИТУДА: 0.22947071493011229
#
# ходьба
#  АМПЛИТУДА: 1.6341049667606051
#
# ходьба
#  АМПЛИТУДА: 1.3724540389471998
#
# ходьба
#  АМПЛИТУДА: 1.7784100359474713
#
# ходьба
#  АМПЛИТУДА: 1.3941750767143504
#
# ходьба
#  АМПЛИТУДА: 1.387736731517673
#
# бег
#  АМПЛИТУДА: 11.698182987452418
#
# бег
#  АМПЛИТУДА: 10.310190084753044
#
# бег
#  АМПЛИТУДА: 6.897714574961241
#
# бег
#  АМПЛИТУДА: 10.755281666718401
#
# велосипед
#  АМПЛИТУДА: 5.711745145598475
#
# велосипед
#  АМПЛИТУДА: 4.200062137157207
#
# велосипед
#  АМПЛИТУДА: 4.637349220491163
#
# велосипед
#  АМПЛИТУДА: 4.405833238115416
#
# лестница
#  АМПЛИТУДА: 1.0193313081215691
#
# лестница
#  АМПЛИТУДА: 1.2513906649975142
#
# лестница
#  АМПЛИТУДА: 1.6300744987089861
#
# лестница
#  АМПЛИТУДА: 1.0801155189691616
#
# стояние
#  АМПЛИТУДА: 0.24905881570960942
#
# стояние
#  АМПЛИТУДА: 0.0400701375309509
#
# стояние
#  АМПЛИТУДА: 0.3537159122435126
#
# стояние
#  АМПЛИТУДА: 0.13599469335824954
#
# ходьба
#  АМПЛИТУДА: 8.28841097581656
#
# ходьба
#  АМПЛИТУДА: 2.8539693101278836
#
# ходьба
#  АМПЛИТУДА: 2.9415260119929476
#
# ходьба
#  АМПЛИТУДА: 2.5127927646259343
#
# автобус
#  АМПЛИТУДА: 0.6359523128551742
#
# автобус
#  АМПЛИТУДА: 0.3329185985343823
#
# автобус
#  АМПЛИТУДА: 0.35833664603819315
#
# бег
#  АМПЛИТУДА: 7.09177010233794
#
# бег
#  АМПЛИТУДА: 8.447666138727056
#
# бег
#  АМПЛИТУДА: 8.803247659852975
#
# бег
#  АМПЛИТУДА: 8.031586833078793
#
# велосипед
#  АМПЛИТУДА: 1.5391817421794287
#
# велосипед
#  АМПЛИТУДА: 0.932883507201275
#
# велосипед
#  АМПЛИТУДА: 0.7097417860397317
#
# велосипед
#  АМПЛИТУДА: 0.9647124900550222
#
# лестница
#  АМПЛИТУДА: 2.9697282903472297
#
# лестница
#  АМПЛИТУДА: 3.127411959453495
#
# лестница
#  АМПЛИТУДА: 2.70136718310036
#
# лестница
#  АМПЛИТУДА: 2.642104960688354
#
# метро
#  АМПЛИТУДА: 0.3806515017895796
#
# метро
#  АМПЛИТУДА: 1.0373227556571465
#
# стояние
#  АМПЛИТУДА: 0.03124620430606151
#
# стояние
#  АМПЛИТУДА: 0.01937875187185123
#
# стояние
#  АМПЛИТУДА: 0.021735603416345284
#
# стояние
#  АМПЛИТУДА: 0.026954051507103394
#
# ходьба
#  АМПЛИТУДА: 3.193063928321477
#
# ходьба
#  АМПЛИТУДА: 3.8963406541453303
#
# ходьба
#  АМПЛИТУДА: 2.714704063755221
#
# ходьба
#  АМПЛИТУДА: 2.569118121097181
#
# лестница
#  АМПЛИТУДА: 4.626648413454264
#
# лестница
#  АМПЛИТУДА: 4.055391257901327
#
# лестница
#  АМПЛИТУДА: 5.143341373913963
#
# лестница
#  АМПЛИТУДА: 4.113450189281318
#
# стояние
#  АМПЛИТУДА: 0.04093693628987016
#
# стояние
#  АМПЛИТУДА: 0.04019479008655302
#
# стояние
#  АМПЛИТУДА: 0.04683940870465242
#
# стояние
#  АМПЛИТУДА: 0.05932588250684068
#
# ходьба
#  АМПЛИТУДА: 5.313731077714931
#
# ходьба
#  АМПЛИТУДА: 5.699345050632549
#
# ходьба
#  АМПЛИТУДА: 4.074318096637376
#
# ходьба
#  АМПЛИТУДА: 4.51030879468531
#
# хотьба
#  АМПЛИТУДА: 2.9446656484956106
#
# хотьба
#  АМПЛИТУДА: 2.383244343854885
#
# хотьба
#  АМПЛИТУДА: 2.776626702964633
#
# хотьба
#  АМПЛИТУДА: 2.94367148251455
#
# Мажорова Инна - Мажорова-велосипед
#  АМПЛИТУДА: 2.715690209189457
#
# велосипед
#  АМПЛИТУДА: 7.725375975131099
#
# ходьба
#  АМПЛИТУДА: 1.9275662511062632
#
# лестница
#  АМПЛИТУДА: 1.2111297807961785
#
# ходьба
#  АМПЛИТУДА: 1.201265531545179
#
# бег
#  АМПЛИТУДА: 7.872661713919318
#
# бег
#  АМПЛИТУДА: 7.240737229301786
#
# бег
#  АМПЛИТУДА: 7.776050673000964
#
# бег
#  АМПЛИТУДА: 9.019713843109887
#
# лестница
#  АМПЛИТУДА: 1.9162902381517368
#
# лестница
#  АМПЛИТУДА: 1.8340447792569878
#
# лестница
#  АМПЛИТУДА: 1.5337316087003101
#
# лестница
#  АМПЛИТУДА: 3.3332287563784213
#
# стояние
#  АМПЛИТУДА: 0.10768457617094962
#
# стояние
#  АМПЛИТУДА: 0.05009936212829613
#
# стояние
#  АМПЛИТУДА: 0.18718335963161004
#
# стояние
#  АМПЛИТУДА: 0.20100246158898039
#
# ходьба
#  АМПЛИТУДА: 3.538310383583901
#
# ходьба
#  АМПЛИТУДА: 2.7020066192478085
#
# ходьба
#  АМПЛИТУДА: 1.2487420777073281
#
# ходьба
#  АМПЛИТУДА: 3.0763603692878276
#
# автобус
#  АМПЛИТУДА: 0.2974947349265056
#
# автобус
#  АМПЛИТУДА: 1.222287216529697
#
# автобус
#  АМПЛИТУДА: 0.343152741409405
#
# автобус
#  АМПЛИТУДА: 0.39740051135936105
#
# стояние
#  АМПЛИТУДА: 0.0747018544092587
#
# стояние
#  АМПЛИТУДА: 0.6503006106482004
#
# стояние
#  АМПЛИТУДА: 0.08188852976202843
#
# стояние
#  АМПЛИТУДА: 1.9928600113612276
#
# ходьба
#  АМПЛИТУДА: 1.153543897151806
#
# ходьба
#  АМПЛИТУДА: 3.2272568636266987
#
# ходьба
#  АМПЛИТУДА: 1.9327990926945047
#
# ходьба
#  АМПЛИТУДА: 1.3660621661707655
#
# автомобиль
#  АМПЛИТУДА: 1.9594336913542718
#
# автомобиль
#  АМПЛИТУДА: 2.3054722530182845
#
# автомобиль
#  АМПЛИТУДА: 2.058640482654297
#
# автомобиль
#  АМПЛИТУДА: 1.4957967962357885
#
# бег
#  АМПЛИТУДА: 5.549295483910466
#
# бег
#  АМПЛИТУДА: 4.60673803528165
#
# бег
#  АМПЛИТУДА: 4.941333031634943
#
# бег
#  АМПЛИТУДА: 5.411605430831194
#
# велосипед
#  АМПЛИТУДА: 3.0029075822890743
#
# велосипед
#  АМПЛИТУДА: 2.952826871056789
#
# велосипед
#  АМПЛИТУДА: 4.861987395740671
#
# велосипед
#  АМПЛИТУДА: 2.876543267377288
#
# стояние
#  АМПЛИТУДА: 0.5897135663547797
#
# стояние
#  АМПЛИТУДА: 0.2926376316389555
#
# стояние
#  АМПЛИТУДА: 0.04701876489580081
#
# стояние
#  АМПЛИТУДА: 0.4690123836213952
#
# ходьба
#  АМПЛИТУДА: 4.082730214995289
#
# ходьба
#  АМПЛИТУДА: 5.347984691225195
#
# ходьба
#  АМПЛИТУДА: 5.354629412177897
#
# ходьба
#  АМПЛИТУДА: 4.359105882279518
#
# бег
#  АМПЛИТУДА: 7.218483098638604
#
# бег
#  АМПЛИТУДА: 6.247085237465038
#
# бег
#  АМПЛИТУДА: 6.688935073048831
#
# бег
#  АМПЛИТУДА: 6.4037217981584345
#
# лестница
#  АМПЛИТУДА: 2.154958648939082
#
# лестница
#  АМПЛИТУДА: 1.5950077157650562
#
# лестница
#  АМПЛИТУДА: 1.7585034150247738
#
# лестница
#  АМПЛИТУДА: 1.9955561661861025
#
# стояние
#  АМПЛИТУДА: 0.04007641680311136
#
# стояние
#  АМПЛИТУДА: 0.03029658302130178
#
# стояние
#  АМПЛИТУДА: 0.027976972668739997
#
# стояние
#  АМПЛИТУДА: 0.03257195060870455
#
# ходьба
#  АМПЛИТУДА: 1.4769915726892129
#
# ходьба
#  АМПЛИТУДА: 1.5934182177409293
#
# ходьба
#  АМПЛИТУДА: 1.5780847490466743
#
# ходьба
#  АМПЛИТУДА: 1.7177376427086486
#
# метро
#  АМПЛИТУДА: 0.34542564852253665
#
# метро
#  АМПЛИТУДА: 0.2851201530613553
#
# метро
#  АМПЛИТУДА: 0.12422938130829186
#
# метро
#  АМПЛИТУДА: 0.23036890120705278
#
# стояние
#  АМПЛИТУДА: 0.38099510040540574
#
# стояние
#  АМПЛИТУДА: 0.20100804961152008
#
# стояние
#  АМПЛИТУДА: 0.570292254932894
#
# стояние
#  АМПЛИТУДА: 0.27562679239026633
#
# автобус
#  АМПЛИТУДА: 0.3467578666223915
#
# автобус
#  АМПЛИТУДА: 0.3993652069300514
#
# автобус
#  АМПЛИТУДА: 0.6260605102412028
#
# автобус
#  АМПЛИТУДА: 0.5696687749646852
#
# бег
#  АМПЛИТУДА: 9.614792487192469
#
# бег
#  АМПЛИТУДА: 8.554848388488283
#
# бег
#  АМПЛИТУДА: 11.572796926147571
#
# бег
#  АМПЛИТУДА: 9.406944694462675
#
# лестница
#  АМПЛИТУДА: 3.4567247985517153
#
# лестница
#  АМПЛИТУДА: 6.131026283439568
#
# лестница
#  АМПЛИТУДА: 4.085874515957448
#
# лестница
#  АМПЛИТУДА: 6.828839557355684
#
# метро
#  АМПЛИТУДА: 0.6414588616155558
#
# метро
#  АМПЛИТУДА: 0.1851488088499721
#
# метро
#  АМПЛИТУДА: 0.5380468552351101
#
# метро
#  АМПЛИТУДА: 1.206399230004302
#
# стояние
#  АМПЛИТУДА: 0.054578452985125536
#
# стояние
#  АМПЛИТУДА: 0.13807761120162276
#
# стояние
#  АМПЛИТУДА: 1.220379019365191
#
# стояние
#  АМПЛИТУДА: 0.20337607390633283
#
# ходьба
#  АМПЛИТУДА: 5.768455027720519
#
# ходьба
#  АМПЛИТУДА: 6.481425554150807
#
# ходьба
#  АМПЛИТУДА: 6.16414923187342
#
# ходьба
#  АМПЛИТУДА: 5.723186368996629
#
# лестница
#  АМПЛИТУДА: 1.4387198290745253
#
# лестница
#  АМПЛИТУДА: 1.369631229987545
#
# лестница
#  АМПЛИТУДА: 1.5766148484119087
#
# лестница
#  АМПЛИТУДА: 1.453259115662985
#
# лестница
#  АМПЛИТУДА: 1.9442508961780438
#
# стояние
#  АМПЛИТУДА: 0.08624279427646298
#
# стояние
#  АМПЛИТУДА: 0.0546891287700596
#
# стояние
#  АМПЛИТУДА: 0.04413390842115894
#
# стояние
#  АМПЛИТУДА: 0.040891095738443295
#
# стояние
#  АМПЛИТУДА: 0.09494506000421443
#
# ходьба
#  АМПЛИТУДА: 1.133963928060219
#
# ходьба
#  АМПЛИТУДА: 1.149753250273557
#
# ходьба
#  АМПЛИТУДА: 1.2653265956535793
#
# ходьба
#  АМПЛИТУДА: 0.9920068233070695
#
# ходьба
#  АМПЛИТУДА: 1.7316577525335481
#
# месте
#  АМПЛИТУДА: 0.03305766677965516
#
# месте
#  АМПЛИТУДА: 0.06333784361071115
#
# месте
#  АМПЛИТУДА: 0.032703663222647616
#
# месте
#  АМПЛИТУДА: 0.06420432058359749
#
# ходьба
#  АМПЛИТУДА: 0.721737938341898
#
# ходьба
#  АМПЛИТУДА: 2.5168990217747753
#
# ходьба
#  АМПЛИТУДА: 3.0083559995743174
#
# ходьба
#  АМПЛИТУДА: 2.0187931760120676
#
# Василевская
#  АМПЛИТУДА: 2.014808003124357
#
# Василевская
#  АМПЛИТУДА: 1.5067239511575798
#
# Василевская
#  АМПЛИТУДА: 2.4931279715998125
#
# Василевская
#  АМПЛИТУДА: 1.6670223959577415
#
# бег
#  АМПЛИТУДА: 8.700749208055107
#
# бег
#  АМПЛИТУДА: 8.515113908609138
#
# бег
#  АМПЛИТУДА: 8.636394718737991
#
# бег
#  АМПЛИТУДА: 7.978905631032019
#
# велосипеде
#  АМПЛИТУДА: 1.9352919542950058
#
# велосипеде
#  АМПЛИТУДА: 2.285820865054815
#
# велосипеде
#  АМПЛИТУДА: 1.7384589784419455
#
# велосипеде
#  АМПЛИТУДА: 2.5564057032793412
#
# лестнице
#  АМПЛИТУДА: 4.549745715572632
#
# лестнице
#  АМПЛИТУДА: 4.887954499405203
#
# лестнице
#  АМПЛИТУДА: 5.039813460010881
#
# лестнице
#  АМПЛИТУДА: 4.058018131694512
#
# месте
#  АМПЛИТУДА: 0.12814726912095542
#
# месте
#  АМПЛИТУДА: 0.02689986151320134
#
# месте
#  АМПЛИТУДА: 0.06287888258294794
#
# месте
#  АМПЛИТУДА: 0.03884908008169352
#
# ходьба
#  АМПЛИТУДА: 6.680582034647873
#
# ходьба
#  АМПЛИТУДА: 4.283275334209674
#
# ходьба
#  АМПЛИТУДА: 4.811621663885349
#
# ходьба
#  АМПЛИТУДА: 3.7154775646143188
#
# Бег
# Бег
# Бег
# Стояние
# Стояние
# Стояние
# Ходьба
# Ходьба
# Ходьба
# автобус
#  АМПЛИТУДА: 0.16466764274328016
#
# автомобиль
#  АМПЛИТУДА: 0.09943799763863315
#
# автомобиль
#  АМПЛИТУДА: 0.05439227922384349
#
# лестница
#  АМПЛИТУДА: 0.1351943447362074
#
# лестница
#  АМПЛИТУДА: 0.9909930165884872
#
# ходьба
#  АМПЛИТУДА: 0.16372954015412333
#
# ходьба
#  АМПЛИТУДА: 0.039022850842616696
#
# ходьба
#  АМПЛИТУДА: 0.11540589564068982
#
# бег
#  АМПЛИТУДА: 9.003704047805146
#
# бег
#  АМПЛИТУДА: 8.430860746808133
#
# бег
#  АМПЛИТУДА: 10.156984674588754
#
# бег
#  АМПЛИТУДА: 9.726202340722109
#
# бег
#  АМПЛИТУДА: 10.67423156063985
#
# бег
#  АМПЛИТУДА: 9.899488713537213
#
# велосипед
#  АМПЛИТУДА: 8.194841483720941
#
# велосипед
#  АМПЛИТУДА: 8.02559335272018
#
# велосипед
#  АМПЛИТУДА: 5.054063033201141
#
# велосипед
#  АМПЛИТУДА: 6.759074677513092
#
# лестница
#  АМПЛИТУДА: 1.8828365851407494
#
# стояние
#  АМПЛИТУДА: 0.17983759295812374
#
# стояние
#  АМПЛИТУДА: 0.15698373091472084
#
# стояние
#  АМПЛИТУДА: 0.6287210784719681
#
# стояние
#  АМПЛИТУДА: 0.7430240330584504
#
# стояние
#  АМПЛИТУДА: 0.05539172833303663
#
# стояние
#  АМПЛИТУДА: 0.19028579764048326
#
# ходьба
#  АМПЛИТУДА: 1.6679154061835426
#
# ходьба
#  АМПЛИТУДА: 1.739084435237333
#
# ходьба
#  АМПЛИТУДА: 2.0007112291373668
#
# ходьба
#  АМПЛИТУДА: 1.4254434388484816
#
# ходьба
#  АМПЛИТУДА: 2.156047153663868
#
# стояние
#  АМПЛИТУДА: 0.21403106278336048
#
# стояние
#  АМПЛИТУДА: 0.061847106175261346
#
# стояние
#  АМПЛИТУДА: 0.9770775841008923
#
# стояние
#  АМПЛИТУДА: 0.5113223936843168
#
# ходьба
#  АМПЛИТУДА: 2.802995603174398
#
# ходьба
#  АМПЛИТУДА: 0.9643743729711133
#
# ходьба
#  АМПЛИТУДА: 0.3431402444128945
#
# ходьба
#  АМПЛИТУДА: 2.2533807045817404
#
# Лущ
#  АМПЛИТУДА: 3.278699940599883
#
# Лущ
#  АМПЛИТУДА: 4.926778949235311
#
# Лущ
#  АМПЛИТУДА: 1.3275864235916186
#
# Лущ
#  АМПЛИТУДА: 3.6189021350414103
#
# лестница
#  АМПЛИТУДА: 3.122739296404647
#
# лестница
#  АМПЛИТУДА: 3.3462528629284036
#
# лестница
#  АМПЛИТУДА: 3.432630476412142
#
# стояние
#  АМПЛИТУДА: 0.09658968451296757
#
# стояние
#  АМПЛИТУДА: 0.09972463510613416
#
# ходьба
#  АМПЛИТУДА: 2.9850693862767548
#
# ходьба
#  АМПЛИТУДА: 3.129887060857558
#
# ходьба
#  АМПЛИТУДА: 2.6640148032484556
#
# ходьба
#  АМПЛИТУДА: 3.7769549815791508
#
# бег
#  АМПЛИТУДА: 6.0514313889194105
#
# бег
#  АМПЛИТУДА: 6.171918461748186
#
# бег
#  АМПЛИТУДА: 0.12108156156211847
#
# бег
#  АМПЛИТУДА: 1.6176704196657754
#
# лестница
#  АМПЛИТУДА: 0.1896074672951269
#
# лестница
#  АМПЛИТУДА: 0.07488875825737262
#
# лестница
#  АМПЛИТУДА: 0.11961114906699077
#
# лестница
#  АМПЛИТУДА: 0.03267315655460812
#
# стояние
#  АМПЛИТУДА: 0.21686549384579445
#
# стояние
#  АМПЛИТУДА: 0.19202169116053958
#
# стояние
#  АМПЛИТУДА: 0.0448869895643742
#
# стояние
#  АМПЛИТУДА: 0.06276286677741838
#
# ходьба
#  АМПЛИТУДА: 3.014702741316985
#
# ходьба
#  АМПЛИТУДА: 0.3097639723371707
#
# ходьба
#  АМПЛИТУДА: 0.3298568254567631
#
# ходьба
#  АМПЛИТУДА: 0.14198738196467353
#
# на
#  АМПЛИТУДА: 0.049365792058466584
#
# Olga - OVP
#  АМПЛИТУДА: 0.8274380098095052
#
# автомобиль
#  АМПЛИТУДА: 0.7871510691290878
#
# автомобиль
#  АМПЛИТУДА: 1.263297470453379
#
# автомобиль
#  АМПЛИТУДА: 0.8210546211889755
#
# автомобиль
#  АМПЛИТУДА: 0.9321740726022844
#
# бег
#  АМПЛИТУДА: 6.25456202101141
#
# бег
#  АМПЛИТУДА: 6.4570083411417105
#
# бег
#  АМПЛИТУДА: 3.5036173059468556
#
# бег
#  АМПЛИТУДА: 3.311552294966037
#
# велосипед
#  АМПЛИТУДА: 0.7909544038395006
#
# велосипед
#  АМПЛИТУДА: 1.8946225226344713
#
# велосипед
#  АМПЛИТУДА: 0.08669303388276262
#
# лестница
#  АМПЛИТУДА: 1.673251484529789
#
# лестница
#  АМПЛИТУДА: 1.7101372188378177
#
# лестница
#  АМПЛИТУДА: 1.686592044804801
#
# лестница
#  АМПЛИТУДА: 2.1027358755075682
#
# стояние
#  АМПЛИТУДА: 0.13299472020976177
#
# стояние
#  АМПЛИТУДА: 0.030105129853547408
#
# стояние
#  АМПЛИТУДА: 0.15233066180194776
#
# стояние
#  АМПЛИТУДА: 0.017190708664544863
#
# ходьба
#  АМПЛИТУДА: 2.262488138488688
#
# ходьба
#  АМПЛИТУДА: 2.721187051729533
#
# ходьба
#  АМПЛИТУДА: 2.670956029695485
#
# ходьба
#  АМПЛИТУДА: 2.4111705964489865
#
# ходьба
#  АМПЛИТУДА: 5.969041301573716
#
# ходьба
#  АМПЛИТУДА: 6.390721785328534
#
# ходьба
#  АМПЛИТУДА: 4.363182352629746
#
# ходьба
#  АМПЛИТУДА: 5.260008137180069
#
# ходьба
#  АМПЛИТУДА: 4.665356868264301
#
# электричка
#  АМПЛИТУДА: 0.3658587643512754
#
# электричка
#  АМПЛИТУДА: 0.3560003760241024
#
# электричка
#  АМПЛИТУДА: 0.3808512109309936
#
# электричка
#  АМПЛИТУДА: 0.26779119989752
#
# автомобиль
#  АМПЛИТУДА: 0.33630712293917076
#
# автомобиль
#  АМПЛИТУДА: 0.5397914926036029
#
# автомобиль
#  АМПЛИТУДА: 0.7136132589945053
#
# автомобиль
#  АМПЛИТУДА: 0.5130401918407924
#
# бег
#  АМПЛИТУДА: 6.400095560338762
#
# бег
#  АМПЛИТУДА: 5.882152014209668
#
# бег
#  АМПЛИТУДА: 5.586801568201182
#
# бег
#  АМПЛИТУДА: 6.075778515749134
#
# лестница
#  АМПЛИТУДА: 1.567329429470186
#
# лестница
#  АМПЛИТУДА: 4.536283367216323
#
# лестница
#  АМПЛИТУДА: 4.660176596643825
#
# лестница
#  АМПЛИТУДА: 3.481344182951605
#
# стояние
#  АМПЛИТУДА: 0.01704009443156662
#
# стояние
#  АМПЛИТУДА: 0.015121277366153207
#
# стояние
#  АМПЛИТУДА: 0.01957016592764249
#
# стояние
#  АМПЛИТУДА: 0.10580357757423109
#
# ходьба
#  АМПЛИТУДА: 2.8886027301480817
#
# ходьба
#  АМПЛИТУДА: 1.5083620544197127
#
# ходьба
#  АМПЛИТУДА: 1.445306070171275
#
# ходьба
#  АМПЛИТУДА: 1.7513252691306362
#
# ходьба
#  АМПЛИТУДА: 1.8194587181596669
#
# велосипед
#  АМПЛИТУДА: 6.667041798749331
#
# автомобиль
#  АМПЛИТУДА: 0.6481754219657311
#
# бег
#  АМПЛИТУДА: 8.804127703396505
#
# бег
#  АМПЛИТУДА: 8.55664654976243
#
# бег
#  АМПЛИТУДА: 8.983360114308931
#
# велосипед
#  АМПЛИТУДА: 10.466890166318542
#
# велосипед
#  АМПЛИТУДА: 2.414566553105275
#
# велосипед
#  АМПЛИТУДА: 3.8854047107900325
#
# лестница
#  АМПЛИТУДА: 2.4551685988272496
#
# лестница
#  АМПЛИТУДА: 4.553792416286313
#
# лестница
#  АМПЛИТУДА: 2.7167816972199312
#
# стояние
#  АМПЛИТУДА: 0.03020226913690416
#
# стояние
#  АМПЛИТУДА: 2.1620786032492894
#
# стояние
#  АМПЛИТУДА: 0.02856165387047538
#
# стояние
#  АМПЛИТУДА: 0.030967418591957285
#
# ходьба
#  АМПЛИТУДА: 3.349697656205646
#
# ходьба
#  АМПЛИТУДА: 6.740430054204164
#
# ходьба
#  АМПЛИТУДА: 3.231978881096749
#
# вел
#  АМПЛИТУДА: 3.822567970239332
#
# вел
#  АМПЛИТУДА: 2.96652259636893
#
# вел
#  АМПЛИТУДА: 3.0951048209788277
#
# вел
#  АМПЛИТУДА: 2.629396554971949
#
# вел
#  АМПЛИТУДА: 4.3007115312269555
#
# бег
#  АМПЛИТУДА: 7.150126191491724
#
# лестница
#  АМПЛИТУДА: 4.264515970655874
#
# стояние
#  АМПЛИТУДА: 0.07759200566547286
#
# стояние
#  АМПЛИТУДА: 0.19128710821228212
#
# ходьба
#  АМПЛИТУДА: 5.773542970573242
#
# бег
#  АМПЛИТУДА: 5.024450942192804
#
# бег
#  АМПЛИТУДА: 5.333426016492542
#
# бег
#  АМПЛИТУДА: 4.1469920808973555
#
# бег
#  АМПЛИТУДА: 4.612089508756936
#
# подъем по лестнице
#  АМПЛИТУДА: 1.1824513011378155
#
# подъем по лестнице
#  АМПЛИТУДА: 0.9774597218485787
#
# подъем по лестнице
#  АМПЛИТУДА: 1.793418408153489
#
# подъем по лестнице
#  АМПЛИТУДА: 1.0426624721807851
#
# поездка в автомобиле
#  АМПЛИТУДА: 1.025213630706368
#
# стояние на месте
#  АМПЛИТУДА: 0.005061429158069841
#
# стояние на месте
#  АМПЛИТУДА: 0.019366207049570816
#
# стояние на месте
#  АМПЛИТУДА: 0.082645591793166
#
# стояние на месте
#  АМПЛИТУДА: 0.15017703760070433
#
# ходьба
#  АМПЛИТУДА: 1.068982715178593
#
# ходьба
#  АМПЛИТУДА: 0.9779359725312868
#
# ходьба
#  АМПЛИТУДА: 1.2144743349445324
#
# ходьба
#  АМПЛИТУДА: 0.6991391617664341
#
# лестница
#  АМПЛИТУДА: 1.5421250511850433
#
# лестница
#  АМПЛИТУДА: 1.4835888535334907
#
# лестница
#  АМПЛИТУДА: 1.3105617784405004
#
# лестница
#  АМПЛИТУДА: 1.4897252456356784
#
# стояние
#  АМПЛИТУДА: 0.11151683717314964
#
# стояние
#  АМПЛИТУДА: 0.2513301627543322
#
# стояние
#  АМПЛИТУДА: 0.035556540998714414
#
# стояние
#  АМПЛИТУДА: 0.033049935943294195
#
# ходьба
#  АМПЛИТУДА: 1.4910132273769454
#
# ходьба
#  АМПЛИТУДА: 1.2353607901357084
#
# ходьба
#  АМПЛИТУДА: 1.3613227689057472
#
# ходьба
#  АМПЛИТУДА: 1.2324445440063783
#
# стояние
#  АМПЛИТУДА: 0.024339080539232394
#
# стояние
#  АМПЛИТУДА: 0.708100813309481
#
# ходьба
#  АМПЛИТУДА: 0.8738185143694028
#
# ходьба
#  АМПЛИТУДА: 1.0766861968432497
#
# автомобиль
#  АМПЛИТУДА: 1.2597124109861002
#
# автомобиль
#  АМПЛИТУДА: 0.8393115222406521
#
# автомобиль
#  АМПЛИТУДА: 1.0987918429413672
#
# автомобиль
#  АМПЛИТУДА: 0.8415810422449711
#
# бег
#  АМПЛИТУДА: 6.604947078884902
#
# бег
#  АМПЛИТУДА: 7.088618014526069
#
# бег
#  АМПЛИТУДА: 8.988512836329559
#
# бег
#  АМПЛИТУДА: 7.881364381884831
#
# велосипед
#  АМПЛИТУДА: 2.2629742818882153
#
# велосипед
#  АМПЛИТУДА: 4.263251424219325
#
# велосипед
#  АМПЛИТУДА: 5.050006707035193
#
# велосипед
#  АМПЛИТУДА: 4.3403288311101065
#
# стояние
#  АМПЛИТУДА: 0.05199441118618797
#
# стояние
#  АМПЛИТУДА: 0.07088080713711631
#
# стояние
#  АМПЛИТУДА: 0.7406742396753657
#
# стояние
#  АМПЛИТУДА: 1.0337964945634641
#
# ходьба
#  АМПЛИТУДА: 7.447114466687612
#
# ходьба
#  АМПЛИТУДА: 4.262635318926133
#
# ходьба
#  АМПЛИТУДА: 5.479734841949148
#
# ходьба
#  АМПЛИТУДА: 4.079793444433166
#
# бег
#  АМПЛИТУДА: 0.5505448380579214
#
# бег
#  АМПЛИТУДА: 0.07866242136577994
#
# бег
#  АМПЛИТУДА: 5.885536322526983
#
# бег
#  АМПЛИТУДА: 5.128713979367338
#
# велосипед
#  АМПЛИТУДА: 0.08429827757771824
#
# велосипед
#  АМПЛИТУДА: 5.26404357169609
#
# велосипед
#  АМПЛИТУДА: 5.858603027727915
#
# велосипед
#  АМПЛИТУДА: 0.03122245999962936
#
# стояние
#  АМПЛИТУДА: 2.7973085451487374
#
# стояние
#  АМПЛИТУДА: 2.002588907576884
#
# стояние
#  АМПЛИТУДА: 1.291567668484249
#
# стояние
#  АМПЛИТУДА: 1.365246886733582
#
# ходьба
#  АМПЛИТУДА: 2.152685563631768
#
# ходьба
#  АМПЛИТУДА: 3.0514726782134542
#
# ходьба
#  АМПЛИТУДА: 3.192683449537773
#
# ходьба
#  АМПЛИТУДА: 2.6363325800258717
#
# Лестница
#  АМПЛИТУДА: 0.7861434137996842
#
# Лестница
#  АМПЛИТУДА: 1.6324899641687913
#
# Лестница
#  АМПЛИТУДА: 2.8218510938216284
#
# Стояние
#  АМПЛИТУДА: 0.04570386185369246
#
# Стояние
#  АМПЛИТУДА: 0.06047079419061119
#
# Стояние
#  АМПЛИТУДА: 0.05026504757470185
#
# Стояние
#  АМПЛИТУДА: 0.07174076997524803
#
# Ходьба
#  АМПЛИТУДА: 3.310333401189949
#
# Ходьба
#  АМПЛИТУДА: 3.698155985766647
#
# Ходьба
#  АМПЛИТУДА: 3.5159928822467896
#
# Ходьба
#  АМПЛИТУДА: 4.3081879342201495
#
# бег
#  АМПЛИТУДА: 4.887857050736768
#
# бег
#  АМПЛИТУДА: 7.198014833899777
#
# бег
#  АМПЛИТУДА: 7.802064693844741
#
# бег
#  АМПЛИТУДА: 5.963562703799367
#
# лестница
#  АМПЛИТУДА: 2.286900804409308
#
# лестница
#  АМПЛИТУДА: 2.6292154765629077
#
# лестница
#  АМПЛИТУДА: 1.8194184873812305
#
# лестница
#  АМПЛИТУДА: 5.323637461243341
#
# стояние
#  АМПЛИТУДА: 0.12060887311811197
#
# стояние
#  АМПЛИТУДА: 0.135135565540916
#
# стояние
#  АМПЛИТУДА: 0.3465298191212165
#
# стояние
#  АМПЛИТУДА: 0.025104701088948134
#
# ходьба
#  АМПЛИТУДА: 0.7480610827066577
#
# ходьба
#  АМПЛИТУДА: 1.514483034190061
#
# ходьба
#  АМПЛИТУДА: 0.700057338151525
#
# ходьба
#  АМПЛИТУДА: 0.8898648493159608
#
# ходьба
#  АМПЛИТУДА: 1.6171882306949255
#
# бег
#  АМПЛИТУДА: 3.470748446400627
#
# бег
#  АМПЛИТУДА: 3.474295910296092
#
# бег
#  АМПЛИТУДА: 3.4773094484651366
#
# бег
#  АМПЛИТУДА: 3.476409439411684
#
# лестница
#  АМПЛИТУДА: 2.0563953110338877
#
# лестница
#  АМПЛИТУДА: 2.461254204301447
#
# лестница
#  АМПЛИТУДА: 1.6063889844712032
#
# лестница
#  АМПЛИТУДА: 2.182440743107529
#
# стояние
#  АМПЛИТУДА: 0.26701715659513636
#
# стояние
#  АМПЛИТУДА: 0.26332997282384873
#
# стояние
#  АМПЛИТУДА: 0.6121225548051881
#
# стояние
#  АМПЛИТУДА: 0.3288424400032779
#
# ходьба
#  АМПЛИТУДА: 1.9550811022918166
#
# ходьба
#  АМПЛИТУДА: 1.9826054286042405
#
# ходьба
#  АМПЛИТУДА: 1.7839788357356956
#
# Ходьба
#  АМПЛИТУДА: 3.2262639944600253
#
# лестница
#  АМПЛИТУДА: 2.6386459817291503
#
# ходьба
#  АМПЛИТУДА: 2.438456608586149
#
# stairs
#  АМПЛИТУДА: 1.2696464993003058
#
# stairs
#  АМПЛИТУДА: 0.7382234637035472
#
# stairs
#  АМПЛИТУДА: 0.8341865128974459
#
# stairs
#  АМПЛИТУДА: 1.2530868543508586
#
# stand
#  АМПЛИТУДА: 0.1410687801836903
#
# stand
#  АМПЛИТУДА: 0.43366925257101674
#
# stand
#  АМПЛИТУДА: 0.06906415415824396
#
# stand
#  АМПЛИТУДА: 0.05837276304117889
#
# бег
#  АМПЛИТУДА: 0.7406972357089516
#
# бег
#  АМПЛИТУДА: 3.6975722788688863
#
# бег
#  АМПЛИТУДА: 1.4042180186300302
#
# бег
#  АМПЛИТУДА: 2.955575097354149
#
# лестница
#  АМПЛИТУДА: 0.09327656160313191
#
# лестница
#  АМПЛИТУДА: 0.21544344402073956
#
# лестница
#  АМПЛИТУДА: 0.1481844822848013
#
# лестница
#  АМПЛИТУДА: 0.11760276438644635
#
# стояние
#  АМПЛИТУДА: 1.0091129148719749
#
# стояние
#  АМПЛИТУДА: 0.1763256284118464
#
# стояние
#  АМПЛИТУДА: 0.16522390734748604
#
# стояние
#  АМПЛИТУДА: 0.10835780921627369
#
# ходьба
#  АМПЛИТУДА: 1.0518944648852488
#
# ходьба
#  АМПЛИТУДА: 1.8025394030357815
#
# ходьба
#  АМПЛИТУДА: 0.20554984789665331
#
# ходьба
#  АМПЛИТУДА: 0.38833429977928635
#
# автобус
#  АМПЛИТУДА: 0.9213957448317955
#
# автобус
#  АМПЛИТУДА: 0.44310096562177115
#
# автобус
#  АМПЛИТУДА: 0.7062950463533717
#
# автобус
#  АМПЛИТУДА: 0.48363132148858246
#
# лестница
#  АМПЛИТУДА: 1.8072741203936666
#
# лестница
#  АМПЛИТУДА: 1.332243659695929
#
# лестница
#  АМПЛИТУДА: 1.3102378705627387
#
# лестница
#  АМПЛИТУДА: 1.1481367491472148
#
# метро
#  АМПЛИТУДА: 0.5217779178510112
#
# метро
#  АМПЛИТУДА: 0.2121061271529796
#
# метро
#  АМПЛИТУДА: 0.23598842639469164
#
# метро
#  АМПЛИТУДА: 0.33760918035600274
#
# ходьба
#  АМПЛИТУДА: 1.3520276021987918
#
# ходьба
#  АМПЛИТУДА: 1.8438732871511687
#
# ходьба
#  АМПЛИТУДА: 0.9241133904757657
#
# ходьба
#  АМПЛИТУДА: 0.8265891258659749
#
# лестница
#  АМПЛИТУДА: 2.253667266934764
#
# стояние
#  АМПЛИТУДА: 0.028162181408291853
#
# ходьба
#  АМПЛИТУДА: 1.8307680491625922
#
# стояние
#  АМПЛИТУДА: 0.07431223387668517
#
# ходьба
#  АМПЛИТУДА: 4.032621667639401
#
# ходьба
#  АМПЛИТУДА: 3.8168117412399494
#
# ходьба
#  АМПЛИТУДА: 3.5697785256263157
#
# бег
#  АМПЛИТУДА: 6.151035010731668
#
# бег
#  АМПЛИТУДА: 7.667097096559314
#
# бег
#  АМПЛИТУДА: 6.980372291029247
#
# бег
#  АМПЛИТУДА: 6.454555690036822
#
# велосипед
#  АМПЛИТУДА: 2.463597762971392
#
# велосипед
#  АМПЛИТУДА: 3.965588813055383
#
# велосипед
#  АМПЛИТУДА: 2.2364036791061443
#
# велосипед
#  АМПЛИТУДА: 2.5187403701860496
#
# стояние
#  АМПЛИТУДА: 0.057394486854916105
#
# стояние
#  АМПЛИТУДА: 0.09723254389266
#
# стояние
#  АМПЛИТУДА: 0.03060324712232032
#
# стояние
#  АМПЛИТУДА: 0.0780925456613184
#
# ходьба
#  АМПЛИТУДА: 5.4976186303754115
#
# ходьба
#  АМПЛИТУДА: 3.4629318415641794
#
# ходьба
#  АМПЛИТУДА: 2.9187522359116813
#
# ходьба
#  АМПЛИТУДА: 3.6775231324417925
#
# велосипед
#  АМПЛИТУДА: 2.410183958618126
#
# велосипед
#  АМПЛИТУДА: 11.062675959255952
#
# велосипед
#  АМПЛИТУДА: 2.5502177537325563
#
# велосипед
#  АМПЛИТУДА: 1.480211407545482
#
# велосипед
#  АМПЛИТУДА: 5.2098535114096425
#
# стояние
#  АМПЛИТУДА: 0.032591165975783376
#
# стояние
#  АМПЛИТУДА: 0.0666210659689116
#
# стояние
#  АМПЛИТУДА: 0.07644244594132832
#
# стояние
#  АМПЛИТУДА: 2.9518364171384834
#
# стояние
#  АМПЛИТУДА: 0.25047575388904053
#
# бег
#  АМПЛИТУДА: 10.335628313759928
#
# бег
#  АМПЛИТУДА: 9.184589844714113
#
# бег
#  АМПЛИТУДА: 9.145063345910774
#
# бег
#  АМПЛИТУДА: 11.527322876505725
#
# велосипед
#  АМПЛИТУДА: 3.911666935426144
#
# велосипед
#  АМПЛИТУДА: 3.018607370139889
#
# велосипед
#  АМПЛИТУДА: 2.2254219851452053
#
# велосипед
#  АМПЛИТУДА: 3.8752480981953195
#
# лестница
#  АМПЛИТУДА: 3.536603590757737
#
# лестница
#  АМПЛИТУДА: 7.200597748404811
#
# лестница
#  АМПЛИТУДА: 2.705071436323471
#
# лестница
#  АМПЛИТУДА: 5.12935274233825
#
# стояние
#  АМПЛИТУДА: 0.017093984397659856
#
# стояние
#  АМПЛИТУДА: 0.019840879887342178
#
# стояние
#  АМПЛИТУДА: 0.015003897357279583
#
# стояние
#  АМПЛИТУДА: 0.02336273562683111
#
# ходьба
#  АМПЛИТУДА: 7.003625070888661
#
# ходьба
#  АМПЛИТУДА: 4.988370327180978
#
# ходьба
#  АМПЛИТУДА: 5.312534534381949
#
# бег
#  АМПЛИТУДА: 4.477173294586337
#
# бег
#  АМПЛИТУДА: 5.508879002600562
#
# бег
#  АМПЛИТУДА: 4.87176959398278
#
# лестница
#  АМПЛИТУДА: 2.237750222156457
#
# стояние
#  АМПЛИТУДА: 0.01385298090949827
#
# стояние
#  АМПЛИТУДА: 0.0712288269744964
#
# стояние
#  АМПЛИТУДА: 0.023155793349900478
#
# стояние
#  АМПЛИТУДА: 0.0960515253807428
#
# ходьба
#  АМПЛИТУДА: 1.5227735805236475
#
# ходьба
#  АМПЛИТУДА: 1.9403789111353746
#
# ходьба
#  АМПЛИТУДА: 1.8983184731764453
#
# ходьба
#  АМПЛИТУДА: 2.9431370246641526

# %% [markdown]
# Напишем функцию для получения предсказания (здесь используется только амплитуда, но в вашем итоговом решении будет больше признаков)

# %%
def get_prediction(ampl):
    if ampl < 1:
        return 0 #стояние
    if ampl >  5:
        return 2 #бег
    return 1 #ходьба

# %%
len(Data), len(Ampl), len(Target)
# Out:
# (649, 649, 649)

# %% [markdown]
# Некоторые амплитуды посчитаны некорректно, уберём соответствующие треки.

# %%
good_indices = [i for i in range(len(Ampl)) if not (math.isnan(Ampl[i]) or Ampl[i]==-1)]

GoodData   = [Data[i] for i in good_indices]
GoodAmpl   = [Ampl[i] for i in good_indices]
GoodTarget = [Target[i] for i in good_indices]

# %%
len(Data), len(GoodData)
# Out:
# (649, 631)

# %% [markdown]
# Создадим таблицу, содержащую номер трека, правильный ответ и предсказание.

# %%
prediction = [get_prediction(a) for a in GoodAmpl]
answer = [get_action(target) for target in GoodTarget]

Res = pd.DataFrame({'track_num' : np.arange(len(GoodData)), 'answer' : answer, 'action' : prediction})
Res.head(10)
# Out:
#    track_num  answer  action
# 0          0       5       1
# 1          1       5       1
# 2          2       5       1
# 3          3       2       1
# 4          4       0       1
# 5          5       1       0
# 6          6       2       2
# 7          7       0       1
# 8          8       1       1
# 9          9       4       0

# %% [markdown]
# Проверим качество нашей модели на тренировочных данных (на данных из открытой папки)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(Res['answer'], Res['action'])
# Out:
# 0.48811410459587956

# %% [markdown]
# В тренировочной папке количество треков разных типов несбалансировано, поэтому для корректной оценки качества нашей модели будем проверять качество модели на таком же распределении треков, как и в тестовой выборке:
#
# * 18% - стояние
# * 18 % - ходьба
# * 18 % - бег
# * 18 % - подъем по лестнице
# * 18 % - велосипед
# * 10% - другие типы движений

# %%
Res['answer'].value_counts(), len(Res)
# Out:
# ( 1    153
#   0    144
#   2    108
#   4     90
#   3     46
#  -1     28
#   5     19
#   6     18
#   7     17
#   8      8
#  Name: answer, dtype: int64,
#  631)

# %%
import random

ind_0 = random.sample(Res[Res.answer == 0].index.tolist(), 46)
ind_1 = random.sample(Res[Res.answer == 1].index.tolist(), 46)
ind_2 = random.sample(Res[Res.answer == 2].index.tolist(), 46)
ind_3 = random.sample(Res[Res.answer == 3].index.tolist(), 46)
ind_4 = random.sample(Res[Res.answer == 4].index.tolist(), 46)
ind_5 = random.sample(Res[Res.answer == 5].index.tolist(), 8)
ind_6 = random.sample(Res[Res.answer == 6].index.tolist(), 8)
ind_7 = random.sample(Res[Res.answer == 7].index.tolist(), 5)
ind_8 = random.sample(Res[Res.answer == 8].index.tolist(), 4)

ind_balanced = ind_0 + ind_1 + ind_2 + ind_3 + ind_4 + ind_5 + ind_6 + ind_7 + ind_8
len(ind_balanced)
# Out:
# 255

# %%
Res_balanced = Res.iloc[ind_balanced]

# %%
accuracy_score(Res_balanced['answer'], Res_balanced['action'])
# Out:
# 0.40784313725490196
