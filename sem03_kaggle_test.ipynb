# %% [markdown]
# ## 2. Получение предсказаний на тестовой выборке и создание файла для kaggle.

# %% [markdown]
# Считаем данные из яндекс-диска

# %%
import os
import pandas as pd
path = r'C:\Users\elena\Desktop\ВШЭ\MiniCourse\kaggle_tracks_correct_open' 
data = {}

Data = []
Target = []

i=0
for dir_entry in sorted(os.listdir(path)):
    dir_entry_path = os.path.join(path, dir_entry)
    if os.path.isfile(dir_entry_path):
        i+=1
        with open(dir_entry_path, 'r') as my_file:
            print(dir_entry_path.split("\\")[-1])
            try:
                df = pd.read_csv(my_file, delimiter=';')
                if df.shape[1] == 5:
                    Data.append(df)
                    Target.append(dir_entry_path.split("\\")[-1])
            except UnicodeDecodeError:
                print(dir_entry_path.split("\\")[-1])
                pass

for dir_entry in sorted(os.listdir(path)):
    dir_entry_path = os.path.join(path, dir_entry)
    if os.path.isfile(dir_entry_path):
        i+=1
        with open(dir_entry_path, 'r') as my_file:
            print(dir_entry_path.split("\\")[-1])
            try:
                df = pd.read_csv(my_file, delimiter=',')
                if df.shape[1] == 5:
                    Data.append(df)
                    Target.append(dir_entry_path.split("\\")[-1])
            except UnicodeDecodeError:
                print(dir_entry_path.split("\\")[-1])
                pass
# Out:
# track_0.csv
# track_1.csv
# track_10.csv
# track_100.csv
# track_101.csv
# track_102.csv
# track_103.csv
# track_104.csv
# track_105.csv
# track_106.csv
# track_107.csv
# track_108.csv
# track_109.csv
# track_11.csv
# track_110.csv
# track_111.csv
# track_112.csv
# track_113.csv
# track_114.csv
# track_115.csv
# track_116.csv
# track_117.csv
# track_118.csv
# track_119.csv
# track_12.csv
# track_120.csv
# track_121.csv
# track_122.csv
# track_123.csv
# track_124.csv
# track_125.csv
# track_126.csv
# track_127.csv
# track_128.csv
# track_129.csv
# track_13.csv
# track_130.csv
# track_131.csv
# track_132.csv
# track_133.csv
# track_134.csv
# track_135.csv
# track_136.csv
# track_137.csv
# track_138.csv
# track_139.csv
# track_14.csv
# track_140.csv
# track_141.csv
# track_142.csv
# track_143.csv
# track_144.csv
# track_145.csv
# track_146.csv
# track_147.csv
# track_148.csv
# track_149.csv
# track_15.csv
# track_150.csv
# track_151.csv
# track_152.csv
# track_153.csv
# track_154.csv
# track_155.csv
# track_156.csv
# track_157.csv
# track_158.csv
# track_159.csv
# track_16.csv
# track_160.csv
# track_161.csv
# track_162.csv
# track_163.csv
# track_164.csv
# track_165.csv
# track_166.csv
# track_167.csv
# track_168.csv
# track_169.csv
# track_17.csv
# track_170.csv
# track_171.csv
# track_172.csv
# track_173.csv
# track_174.csv
# track_175.csv
# track_176.csv
# track_177.csv
# track_178.csv
# track_179.csv
# track_18.csv
# track_180.csv
# track_181.csv
# track_182.csv
# track_19.csv
# track_2.csv
# track_20.csv
# track_21.csv
# track_22.csv
# track_23.csv
# track_24.csv
# track_25.csv
# track_26.csv
# track_27.csv
# track_28.csv
# track_29.csv
# track_3.csv
# track_30.csv
# track_31.csv
# track_32.csv
# track_33.csv
# track_34.csv
# track_35.csv
# track_36.csv
# track_37.csv
# track_38.csv
# track_39.csv
# track_4.csv
# track_40.csv
# track_41.csv
# track_42.csv
# track_43.csv
# track_44.csv
# track_45.csv
# track_46.csv
# track_47.csv
# track_48.csv
# track_49.csv
# track_5.csv
# track_50.csv
# track_51.csv
# track_52.csv
# track_53.csv
# track_54.csv
# track_55.csv
# track_56.csv
# track_57.csv
# track_58.csv
# track_59.csv
# track_6.csv
# track_60.csv
# track_61.csv
# track_62.csv
# track_63.csv
# track_64.csv
# track_65.csv
# track_66.csv
# track_67.csv
# track_68.csv
# track_69.csv
# track_7.csv
# track_70.csv
# track_71.csv
# track_72.csv
# track_73.csv
# track_74.csv
# track_75.csv
# track_76.csv
# track_77.csv
# track_78.csv
# track_79.csv
# track_8.csv
# track_80.csv
# track_81.csv
# track_82.csv
# track_83.csv
# track_84.csv
# track_85.csv
# track_86.csv
# track_87.csv
# track_88.csv
# track_89.csv
# track_9.csv
# track_90.csv
# track_91.csv
# track_92.csv
# track_93.csv
# track_94.csv
# track_95.csv
# track_96.csv
# track_97.csv
# track_98.csv
# track_99.csv
# track_0.csv
# track_1.csv
# track_10.csv
# track_100.csv
# track_101.csv
# track_102.csv
# track_103.csv
# track_104.csv
# track_105.csv
# track_106.csv
# track_107.csv
# track_108.csv
# track_109.csv
# track_11.csv
# track_110.csv
# track_111.csv
# track_112.csv
# track_113.csv
# track_114.csv
# track_115.csv
# track_116.csv
# track_117.csv
# track_118.csv
# track_119.csv
# track_12.csv
# track_120.csv
# track_121.csv
# track_122.csv
# track_123.csv
# track_124.csv
# track_125.csv
# track_126.csv
# track_127.csv
# track_128.csv
# track_129.csv
# track_13.csv
# track_130.csv
# track_131.csv
# track_132.csv
# track_133.csv
# track_134.csv
# track_135.csv
# track_136.csv
# track_137.csv
# track_138.csv
# track_139.csv
# track_14.csv
# track_140.csv
# track_141.csv
# track_142.csv
# track_143.csv
# track_144.csv
# track_145.csv
# track_146.csv
# track_147.csv
# track_148.csv
# track_149.csv
# track_15.csv
# track_150.csv
# track_151.csv
# track_152.csv
# track_153.csv
# track_154.csv
# track_155.csv
# track_156.csv
# track_157.csv
# track_158.csv
# track_159.csv
# track_16.csv
# track_160.csv
# track_161.csv
# track_162.csv
# track_163.csv
# track_164.csv
# track_165.csv
# track_166.csv
# track_167.csv
# track_168.csv
# track_169.csv
# track_17.csv
# track_170.csv
# track_171.csv
# track_172.csv
# track_173.csv
# track_174.csv
# track_175.csv
# track_176.csv
# track_177.csv
# track_178.csv
# track_179.csv
# track_18.csv
# track_180.csv
# track_181.csv
# track_182.csv
# track_19.csv
# track_2.csv
# track_20.csv
# track_21.csv
# track_22.csv
# track_23.csv
# track_24.csv
# track_25.csv
# track_26.csv
# track_27.csv
# track_28.csv
# track_29.csv
# track_3.csv
# track_30.csv
# track_31.csv
# track_32.csv
# track_33.csv
# track_34.csv
# track_35.csv
# track_36.csv
# track_37.csv
# track_38.csv
# track_39.csv
# track_4.csv
# track_40.csv
# track_41.csv
# track_42.csv
# track_43.csv
# track_44.csv
# track_45.csv
# track_46.csv
# track_47.csv
# track_48.csv
# track_49.csv
# track_5.csv
# track_50.csv
# track_51.csv
# track_52.csv
# track_53.csv
# track_54.csv
# track_55.csv
# track_56.csv
# track_57.csv
# track_58.csv
# track_59.csv
# track_6.csv
# track_60.csv
# track_61.csv
# track_62.csv
# track_63.csv
# track_64.csv
# track_65.csv
# track_66.csv
# track_67.csv
# track_68.csv
# track_69.csv
# track_7.csv
# track_70.csv
# track_71.csv
# track_72.csv
# track_73.csv
# track_74.csv
# track_75.csv
# track_76.csv
# track_77.csv
# track_78.csv
# track_79.csv
# track_8.csv
# track_80.csv
# track_81.csv
# track_82.csv
# track_83.csv
# track_84.csv
# track_85.csv
# track_86.csv
# track_87.csv
# track_88.csv
# track_89.csv
# track_9.csv
# track_90.csv
# track_91.csv
# track_92.csv
# track_93.csv
# track_94.csv
# track_95.csv
# track_96.csv
# track_97.csv
# track_98.csv
# track_99.csv

# %% [markdown]
# Обработаем данные и извлечём признаки для создания модели

# %%
import pandas as pd
from matplotlib import pylab as plt
# %pylab inline

def process_data(df, comma=True, cut=True, name = "", a=-1, b=-1):
    
# обрезаем начало и конец трека
    if a == -1:
        st = int(0.2*len(df))
    else:
        st = a
            
    if b == -1:
        end = -int(0.2*len(df))
    else:
        end = b
        
    if cut == False:
        st = 0
        end = -1

    print(name)
#     fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2, figsize=(15,6))

# приводим данные с Iphone к нужному формату
    if comma is True:
        df = df.applymap(lambda x: str(x).replace(',','.'))
        
        try:
            df['gFx'] = df['gFx'].astype(float)
            df['gFy'] = df['gFy'].astype(float)
            df['gFz'] = df['gFz'].astype(float)
        except KeyError:
            return -1

# рисуем графики ускорений
#     if cut:
#         ax1.plot(df.iloc[st:end]['gFx'],c='g')
#         ax1.plot(df.iloc[st:end]['gFy'],c='r')
#         ax1.plot(df.iloc[st:end]['gFz'],c='b')
#     else:
#         ax1.plot(df['gFx'],c='g')
#         ax1.plot(df['gFy'],c='r')
#         ax1.plot(df['gFz'],c='b')
        
# вычисляем модуль (норму) ускорения и рисуем его
    Acc = (df.gFx[st:end] ** 2 + df.gFy[st:end] ** 2 + df.gFz[st:end] ** 2) ** 0.5
#     ax2.plot(Acc)
#     plt.show()

# можно различить многие действия по амплитуде ускорения
    amplitude = Acc.max() - Acc.min()
    print(' АМПЛИТУДА:', Acc.max()-Acc.min())
    print()
    
    return amplitude

Ampl = np.zeros(len(Data)) 

for df, target in zip(Data,Target):
    track_num = int(target.split('_')[1].split('.')[0]) # важный момент, что треки идут не по нумерации (а в лексикографическом порядке)!
    Ampl[track_num] = process_data(df, name=target)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# track_52.csv
#  АМПЛИТУДА: 2.9338561302413355
#
# track_0.csv
#  АМПЛИТУДА: 0.22579018436925802
#
# track_1.csv
#  АМПЛИТУДА: 1.037319895576775
#
# track_10.csv
#  АМПЛИТУДА: 1.804136939075257
#
# track_100.csv
# C:\Users\elena\AppData\Roaming\Python\Python37\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
#  АМПЛИТУДА: 4.6333212367445284
#
# track_101.csv
#  АМПЛИТУДА: 3.3876988170840905
#
# track_102.csv
#  АМПЛИТУДА: 2.8452328938042064
#
# track_103.csv
#  АМПЛИТУДА: 0.8419909187113498
#
# track_104.csv
#  АМПЛИТУДА: 7.469392166951225
#
# track_105.csv
#  АМПЛИТУДА: 0.03908438102836409
#
# track_106.csv
#  АМПЛИТУДА: 2.4934347297466832
#
# track_107.csv
#  АМПЛИТУДА: 1.3694113030743247
#
# track_108.csv
#  АМПЛИТУДА: 6.177405627952268
#
# track_109.csv
#  АМПЛИТУДА: 2.1041070751830127
#
# track_11.csv
#  АМПЛИТУДА: 0.019328988887354348
#
# track_110.csv
#  АМПЛИТУДА: 4.980696128907414
#
# track_111.csv
#  АМПЛИТУДА: 2.182579331980982
#
# track_112.csv
#  АМПЛИТУДА: 3.945263984504415
#
# track_113.csv
#  АМПЛИТУДА: 8.101851877841113
#
# track_114.csv
#  АМПЛИТУДА: 2.2618114437103363
#
# track_115.csv
#  АМПЛИТУДА: 1.568883594913017
#
# track_116.csv
#  АМПЛИТУДА: 0.042436878839561376
#
# track_117.csv
#  АМПЛИТУДА: 3.351669199081363
#
# track_118.csv
#  АМПЛИТУДА: 1.5971098574254567
#
# track_119.csv
#  АМПЛИТУДА: 1.8580239992320757
#
# track_12.csv
#  АМПЛИТУДА: 5.0103722896175285
#
# track_120.csv
#  АМПЛИТУДА: 5.848391838610253
#
# track_121.csv
#  АМПЛИТУДА: 6.617606079414956
#
# track_122.csv
#  АМПЛИТУДА: 0.4194272222654043
#
# track_123.csv
#  АМПЛИТУДА: 4.905555263566797
#
# track_124.csv
#  АМПЛИТУДА: 2.8290340370565588
#
# track_125.csv
#  АМПЛИТУДА: 6.750243068198256
#
# track_126.csv
#  АМПЛИТУДА: 0.2932006013951691
#
# track_127.csv
#  АМПЛИТУДА: 7.496686746491644
#
# track_128.csv
#  АМПЛИТУДА: 1.3694113030743247
#
# track_129.csv
#  АМПЛИТУДА: 1.259116098908134
#
# track_13.csv
#  АМПЛИТУДА: 2.617663370775875
#
# track_130.csv
#  АМПЛИТУДА: 2.6278376772731593
#
# track_131.csv
#  АМПЛИТУДА: 0.037702452391269126
#
# track_132.csv
#  АМПЛИТУДА: 2.4565741360291082
#
# track_133.csv
#  АМПЛИТУДА: 0.009305967647839086
#
# track_134.csv
#  АМПЛИТУДА: 0.1442090378393016
#
# track_135.csv
#  АМПЛИТУДА: 8.833789142567072
#
# track_136.csv
#  АМПЛИТУДА: 4.364114709035295
#
# track_137.csv
#  АМПЛИТУДА: 9.43369600102802
#
# track_138.csv
#  АМПЛИТУДА: 9.978477527931528
#
# track_139.csv
#  АМПЛИТУДА: 4.26989411563841
#
# track_14.csv
#  АМПЛИТУДА: 9.379525566043048
#
# track_140.csv
#  АМПЛИТУДА: 1.5270963119058862
#
# track_141.csv
#  АМПЛИТУДА: 5.687705532588813
#
# track_142.csv
#  АМПЛИТУДА: 2.4185341114208763
#
# track_143.csv
#  АМПЛИТУДА: 3.8714815696049416
#
# track_144.csv
#  АМПЛИТУДА: 9.793314652916319
#
# track_145.csv
#  АМПЛИТУДА: 0.035126023631020686
#
# track_146.csv
#  АМПЛИТУДА: 0.741920211510277
#
# track_147.csv
#  АМПЛИТУДА: 9.126147536885268
#
# track_148.csv
#  АМПЛИТУДА: 1.073553082723471
#
# track_149.csv
#  АМПЛИТУДА: 2.1595759308422626
#
# track_15.csv
#  АМПЛИТУДА: 0.40739804202290364
#
# track_150.csv
#  АМПЛИТУДА: 8.35371874253114
#
# track_151.csv
#  АМПЛИТУДА: 1.126466638805242
#
# track_152.csv
#  АМПЛИТУДА: 2.8290340370565588
#
# track_153.csv
#  АМПЛИТУДА: 1.7770006048844085
#
# track_154.csv
#  АМПЛИТУДА: 3.2336263738824056
#
# track_155.csv
#  АМПЛИТУДА: 7.203262650230073
#
# track_156.csv
#  АМПЛИТУДА: 5.862921363594969
#
# track_157.csv
#  АМПЛИТУДА: 5.800172247269958
#
# track_158.csv
#  АМПЛИТУДА: 7.45458401261661
#
# track_159.csv
#  АМПЛИТУДА: 0.31653590237306173
#
# track_16.csv
#  АМПЛИТУДА: 6.775423308429975
#
# track_160.csv
#  АМПЛИТУДА: 0.2118250570944642
#
# track_161.csv
#  АМПЛИТУДА: 1.1591739528475085
#
# track_162.csv
#  АМПЛИТУДА: 0.06644780954833251
#
# track_163.csv
#  АМПЛИТУДА: 3.641858119464983
#
# track_164.csv
#  АМПЛИТУДА: 0.9643450844992407
#
# track_165.csv
#  АМПЛИТУДА: 1.805986925307177
#
# track_166.csv
#  АМПЛИТУДА: 3.67520134239017
#
# track_167.csv
#  АМПЛИТУДА: 5.864704163131021
#
# track_168.csv
#  АМПЛИТУДА: 9.250677861367551
#
# track_169.csv
#  АМПЛИТУДА: 2.407250674120206
#
# track_17.csv
#  АМПЛИТУДА: 1.1934628328405692
#
# track_170.csv
#  АМПЛИТУДА: 2.124336238883378
#
# track_171.csv
#  АМПЛИТУДА: 2.76747032033991
#
# track_172.csv
#  АМПЛИТУДА: 0.028106668417903657
#
# track_173.csv
#  АМПЛИТУДА: 0.8419909187113498
#
# track_174.csv
#  АМПЛИТУДА: 6.155487366258161
#
# track_175.csv
#  АМПЛИТУДА: 3.1563878824421536
#
# track_176.csv
#  АМПЛИТУДА: 0.11063557029413362
#
# track_177.csv
#  АМПЛИТУДА: 0.5447078249883448
#
# track_178.csv
#  АМПЛИТУДА: 3.228322334766254
#
# track_179.csv
#  АМПЛИТУДА: 8.514783791894512
#
# track_18.csv
#  АМПЛИТУДА: 0.49022059838477616
#
# track_180.csv
#  АМПЛИТУДА: 1.4775700039777937
#
# track_181.csv
#  АМПЛИТУДА: 4.692031282712372
#
# track_182.csv
#  АМПЛИТУДА: 0.046480502101215904
#
# track_19.csv
#  АМПЛИТУДА: 3.1773385538422643
#
# track_2.csv
#  АМПЛИТУДА: 1.0227958596514302
#
# track_20.csv
#  АМПЛИТУДА: 0.9418348340770927
#
# track_21.csv
#  АМПЛИТУДА: 3.7685366505050606
#
# track_22.csv
#  АМПЛИТУДА: 0.04671256612226504
#
# track_23.csv
#  АМПЛИТУДА: 3.221241492963948
#
# track_24.csv
#  АМПЛИТУДА: 4.699822299593985
#
# track_25.csv
#  АМПЛИТУДА: 6.06844631764062
#
# track_26.csv
#  АМПЛИТУДА: 0.5246140935582272
#
# track_27.csv
#  АМПЛИТУДА: 2.76747032033991
#
# track_28.csv
#  АМПЛИТУДА: 1.837700850765664
#
# track_29.csv
#  АМПЛИТУДА: 2.492846100466425
#
# track_3.csv
#  АМПЛИТУДА: 0.22278989113416114
#
# track_30.csv
#  АМПЛИТУДА: 2.3646269061128375
#
# track_31.csv
#  АМПЛИТУДА: 0.03335622363921886
#
# track_32.csv
#  АМПЛИТУДА: 0.03670077887359957
#
# track_33.csv
#  АМПЛИТУДА: 3.0012137798719314
#
# track_34.csv
#  АМПЛИТУДА: 2.4565741360291082
#
# track_35.csv
#  АМПЛИТУДА: 7.069972999638185
#
# track_36.csv
#  АМПЛИТУДА: 0.11575952467634432
#
# track_37.csv
#  АМПЛИТУДА: 1.7496778171718206
#
# track_38.csv
#  АМПЛИТУДА: 4.642029071455042
#
# track_39.csv
#  АМПЛИТУДА: 0.11063557029413362
#
# track_4.csv
#  АМПЛИТУДА: 0.3402407681738169
#
# track_40.csv
#  АМПЛИТУДА: 0.015495409189059228
#
# track_41.csv
#  АМПЛИТУДА: 9.029583050099246
#
# track_42.csv
#  АМПЛИТУДА: 10.139216573175817
#
# track_43.csv
#  АМПЛИТУДА: 2.124336238883378
#
# track_44.csv
#  АМПЛИТУДА: 4.52880022249668
#
# track_45.csv
#  АМПЛИТУДА: 1.6423394166452296
#
# track_46.csv
#  АМПЛИТУДА: 3.468369477393101
#
# track_47.csv
#  АМПЛИТУДА: 1.0520805860431857
#
# track_48.csv
#  АМПЛИТУДА: 0.12532367760529772
#
# track_49.csv
#  АМПЛИТУДА: 1.9254004237871036
#
# track_5.csv
#  АМПЛИТУДА: 0.23734383025525774
#
# track_50.csv
#  АМПЛИТУДА: 1.0096441429932248
#
# track_51.csv
#  АМПЛИТУДА: 1.5117563691489093
#
# track_53.csv
#  АМПЛИТУДА: 0.08115205732605402
#
# track_54.csv
#  АМПЛИТУДА: 3.968491044559421
#
# track_55.csv
#  АМПЛИТУДА: 0.9800462950410067
#
# track_56.csv
#  АМПЛИТУДА: 0.9047656508173252
#
# track_57.csv
#  АМПЛИТУДА: 2.176036691332483
#
# track_58.csv
#  АМПЛИТУДА: 3.267092868372187
#
# track_59.csv
#  АМПЛИТУДА: 1.5117563691489093
#
# track_6.csv
#  АМПЛИТУДА: 2.5835429119223496
#
# track_60.csv
#  АМПЛИТУДА: 1.2919799758880233
#
# track_61.csv
#  АМПЛИТУДА: 3.3624614701244164
#
# track_62.csv
#  АМПЛИТУДА: 9.293501190500901
#
# track_63.csv
#  АМПЛИТУДА: 2.6278376772731593
#
# track_64.csv
#  АМПЛИТУДА: 3.1243961620554765
#
# track_65.csv
#  АМПЛИТУДА: 2.493435844215357
#
# track_66.csv
#  АМПЛИТУДА: 0.27314123512322563
#
# track_67.csv
#  АМПЛИТУДА: 1.4049403140963879
#
# track_68.csv
#  АМПЛИТУДА: 2.3646269061128375
#
# track_69.csv
#  АМПЛИТУДА: 0.029626152007814266
#
# track_7.csv
#  АМПЛИТУДА: 0.512945962492874
#
# track_70.csv
#  АМПЛИТУДА: 0.006989831534656599
#
# track_71.csv
#  АМПЛИТУДА: 6.151439856806816
#
# track_72.csv
#  АМПЛИТУДА: 2.619205131477962
#
# track_73.csv
#  АМПЛИТУДА: 4.025609690024341
#
# track_74.csv
#  АМПЛИТУДА: 2.0100313391555695
#
# track_75.csv
#  АМПЛИТУДА: 0.015535178729085719
#
# track_76.csv
#  АМПЛИТУДА: 5.4462395245532695
#
# track_77.csv
#  АМПЛИТУДА: 0.042027234773925115
#
# track_78.csv
#  АМПЛИТУДА: 2.67252757321182
#
# track_79.csv
#  АМПЛИТУДА: 0.03555294586486302
#
# track_8.csv
#  АМПЛИТУДА: 0.1095454928175904
#
# track_80.csv
#  АМПЛИТУДА: 0.033711394862443456
#
# track_81.csv
#  АМПЛИТУДА: 0.045128540043802734
#
# track_82.csv
#  АМПЛИТУДА: 0.9585710148889119
#
# track_83.csv
#  АМПЛИТУДА: 0.014446805207625646
#
# track_84.csv
#  АМПЛИТУДА: 3.1627411772799774
#
# track_85.csv
#  АМПЛИТУДА: 6.321926677202568
#
# track_86.csv
#  АМПЛИТУДА: 3.7807136548572
#
# track_87.csv
#  АМПЛИТУДА: 8.830140717365287
#
# track_88.csv
#  АМПЛИТУДА: 7.376276708180853
#
# track_89.csv
#  АМПЛИТУДА: 1.7496778171718206
#
# track_9.csv
#  АМПЛИТУДА: 0.48974070160377203
#
# track_90.csv
#  АМПЛИТУДА: 2.176780929535323
#
# track_91.csv
# track_92.csv
#  АМПЛИТУДА: 2.8218510938216284
#
# track_93.csv
#  АМПЛИТУДА: 2.072169419687453
#
# track_94.csv
#  АМПЛИТУДА: 6.991710054107244
#
# track_95.csv
#  АМПЛИТУДА: 1.6934828504953505
#
# track_96.csv
#  АМПЛИТУДА: 0.011453576977329405
#
# track_97.csv
#  АМПЛИТУДА: 0.037964374659053446
#
# track_98.csv
#  АМПЛИТУДА: 1.8580239992320757
#
# track_99.csv
#  АМПЛИТУДА: 0.2173434292288038

# %% [markdown]
# Напишем функцию для получения предсказания (здесь используется только амплитуда, но в вашем итоговом решении будет больше признаков)

# %%
def get_prediction(ampl):
    if ampl < 1:
        return 0 #стояние
    if ampl >  5:
        return 2 #бег
    return 1 #ходьба

# %%
len(Data), len(Ampl), len(Target)
# Out:
# (183, 183, 183)

# %% [markdown]
# У скольких треков определяется амплитуда?

# %%
i=0
for elem in Ampl:
    if not (math.isnan(elem) or elem == -1):
        i+=1
i
# Out:
# 182

# %% [markdown]
# Создадим таблицу, содержащую номер трека и предсказание.

# %%
prediction = [get_prediction(a) for a in Ampl]

Res = pd.DataFrame({'track_num' : np.arange(len(Data)), 'action' : prediction})
Res.head(10)
# Out:
#    track_num  action
# 0          0       0
# 1          1       1
# 2          2       1
# 3          3       0
# 4          4       0
# 5          5       0
# 6          6       1
# 7          7       0
# 8          8       0
# 9          9       0

# %%
Res.to_csv("first_submit_correct_open.csv", index=False)
